# %% [markdown]
# # Question 5, Option C, Step I: Search for Nearest K Origination Point

# %% [markdown]
# Author's Workday ID: C175799, Initials: RPR

# %% [markdown]
# ## Imports and Util Functions

# %%
import pandas as pd
import numpy as np
import time
import datetime
from math import radians, cos, sin, asin, sqrt
from haversine import haversine
import math
import random
from multiprocessing import Process, current_process
import hashlib

def get_time( output=True ):
    
    """
    Simple util to get system time and dump it to console automagically
    """
    temp = time.time()
    if output:
        now = datetime.datetime.now()
        print( now.strftime( "%Y.%m.%d %H:%M" ) )
        
    return temp

foo = get_time()

def print_time( start_time, end_time, interval="seconds" ):
    
    """
    Simple util to calculate elapsed time and dump it to console automagically
    """
    
    if interval == "hours":
        print ( "Time to process: [%s] hours" % ( str( ( end_time - start_time ) / 60 / 60 ) ) )
    else:
        print ( "Time to process: [%s] seconds" % ( str( end_time - start_time ) ) )

print_time( 0, 3600 )
print_time( 0, 3600, interval="hours" )
# Out:
# 2018.05.09 13:27
# Time to process: [3600] seconds
# Time to process: [1.0] hours

# %% [markdown]
# ## Load Trips Data, Previously Cleaned for Q4

# %%
start_time = get_time()
trips = pd.read_csv( "data/green-tripdata-2015-09-cleaned.csv" )
end_time = get_time()
print_time( start_time, end_time )

# drop superfluous fields
trips.drop( columns=[ "vendorid", "store_and_fwd_flag", "ratecodeid", "passenger_count", "fare_amount", "extra", "mta_tax", "tip_amount", "tolls_amount", "improvement_surcharge", "total_amount", "payment_type", "trip_type", "tip_percent", "credit_card", "tip_recorded" ], inplace=True )
# Out:
# 2018.05.09 13:27
# 2018.05.09 13:27
# Time to process: [2.64208722114563] seconds

# %% [markdown]
# ## Create Lookup Table and Function to Calculate Mean MPH

# %%
# build lookup table for mph by day and hour, takes advantage of Panda's indexing of group_by indexing.
trips_mph_day_n_hour_grp = trips.groupby( [ "pickup_day_of_week", "pickup_hour" ] )
trips_mph_day_n_hour = trips_mph_day_n_hour_grp[ "speed_mph" ].mean()

def get_mph( day, hour ):
    
    return trips_mph_day_n_hour[ day ][ hour ]

now = datetime.datetime.now()
get_mph( now.weekday(), now.hour )
# Out:
# 11.249633747142711

# %% [markdown]
# ## Calculate Time to Traverse City from Where Taxis is to Where Pickup Is

# %%
def get_time_to_pickup( pickup_day, pickup_hour, pickup_lat_lon, taxi_lat_lon, interval="minutes", debug="False" ):
    
    distance = haversine( pickup_lat_lon, taxi_lat_lon, miles=True )
    mph = get_mph( pickup_day, pickup_hour )
    
    if debug:
        print( "distance:", distance, "miles @", mph, "mph" )
        
    if ( interval == "hours" ):
        return ( distance / mph )
    else: # defaults to minutes
        return ( distance / mph ) * 60

# %% [markdown]
# ### Test get_time_to_pickup(...)

# %%
# build time from here to there at a given time of day
from_lat = 40.7128
from_lon = -73.979485
#to_lat = 40.6128
#to_lon = -73.879485

pickup_location = ( from_lat, from_lon )
taxi_location = ( from_lat - 0.01, from_lon - 0.01 )

print( "Minutes to pickup:", get_time_to_pickup( now.weekday(), now.hour, pickup_location, taxi_location, debug=True ) )
print()
print( "  Hours to pickup:", get_time_to_pickup( now.weekday(), now.hour, pickup_location, taxi_location, interval="hours", debug=True ) )
# Out:
# distance: 0.8670130524375171 miles @ 11.2496337471 mph
# Minutes to pickup: 4.62422015823
#
# distance: 0.8670130524375171 miles @ 11.2496337471 mph
#   Hours to pickup: 0.0770703359705

# %% [markdown]
# ### What Are the Means?

# %%
# what's the mean mph across all trips?
mean_mph = trips.speed_mph.mean()
print( "Mean MPH:", mean_mph )
mean_distance = trips.trip_distance.mean()
print( "Mean Distance:", mean_distance )
mean_duration = trips.trip_duration_mins.mean()
print( "Mean Duration:", mean_duration, "minutes" )
# Out:
# Mean MPH: 12.477215717
# Mean Distance: 2.85825795027
# Mean Duration: 20.4071485747 minutes

# %% [markdown]
# ## Calculate Bearing from Pickup to Dropoff: Moved to Data Cleanup

# %%
# # From: https://gist.github.com/jeromer/2005586
# def calculate_initial_compass_bearing( pointA, pointB ):
#     """
#     Calculates the bearing between two points.
#     The formulae used is the following:
#         θ = atan2(sin(Δlong).cos(lat2),
#                   cos(lat1).sin(lat2) − sin(lat1).cos(lat2).cos(Δlong))
#     :Parameters:
#       - `pointA: The tuple representing the latitude/longitude for the
#         first point. Latitude and longitude must be in decimal degrees
#       - `pointB: The tuple representing the latitude/longitude for the
#         second point. Latitude and longitude must be in decimal degrees
#     :Returns:
#       The bearing in degrees
#     :Returns Type:
#       float
#     """
#     if (type(pointA) != tuple) or (type(pointB) != tuple):
#         raise TypeError("Only tuples are supported as arguments")

#     lat1 = math.radians(pointA[0])
#     lat2 = math.radians(pointB[0])

#     diffLong = math.radians(pointB[1] - pointA[1])

#     x = math.sin(diffLong) * math.cos(lat2)
#     y = math.cos(lat1) * math.sin(lat2) - (math.sin(lat1)
#             * math.cos(lat2) * math.cos(diffLong))

#     initial_bearing = math.atan2(x, y)

#     # Now we have the initial bearing but math.atan2 return values
#     # from -180° to + 180° which is not what we want for a compass bearing
#     # The solution is to normalize the initial bearing as shown below
#     initial_bearing = math.degrees(initial_bearing)
#     compass_bearing = (initial_bearing + 360) % 360

#     return compass_bearing

# %% [markdown]
# ### Test calculate_initial_compass_bearing(...)

# %%
# # get bearing between dc and nyc: https://www.distancefromto.net/distance-from-washington-d-c-to-new-york
# dc = ( 38.90719, -77.03687 )
# nyc = ( 40.71278, -74.00594 )
# print( calculate_initial_compass_bearing( dc, nyc ) )
# print( calculate_initial_compass_bearing( nyc, dc ) )

# %% [markdown]
# ## Create Wrapper for Calculating Bearing from Pickup to Dropoff Lat/Lons

# %%
# def get_bearing( row ):
    
#     pickup = ( row.pickup_latitude, row.pickup_longitude )
#     dropoff = ( row.dropoff_latitude, row.dropoff_longitude )
    
#     return calculate_initial_compass_bearing( pickup, dropoff )

# %% [markdown]
# ## Calculate Bearing for All Pickups in Trips DF

# %%
# start_time = get_time()
# trips[ "pickup_bearing" ] = trips.apply( get_bearing, axis=1 )
# print_time( start_time, get_time()  )

# %% [markdown]
# ## Create lat/lon bins for Search and Simulation Optimization

# %%
# build pre-calc'd lookup for n-closest taxis
trips[ "pickup_latitude_bin_1" ] = round( trips.pickup_latitude, 1 )
trips[ "pickup_latitude_bin_2" ] = round( trips.pickup_latitude, 2 )
trips[ "pickup_longitude_bin_1" ] = round( trips.pickup_longitude, 1 )
trips[ "pickup_longitude_bin_2" ] = round( trips.pickup_longitude, 2 )

# %% [markdown]
# ## Find Nearby Taxis w/in a Given Lat/Lon Window, for a Given Day/Hour

# %%
def get_taxis_by_pickups( day, hour, lat_full, lon_full, rounding_places, margin ):

    """
    Queries trips df using full precision pickup lat/long.
    Uses a combination of rounding of taxi hailer's lat/lons + margin value to create a window for nearby taxis.
    Because we're querying df of a month's worth of pickups, we also need to use 'day_of_week_mean' as shorthand 
    for 'on average, how many taxis are picking up on a given day and hour w/in this lat/lon window.
    """
    # To calculate mean availability per hour bin, we need to create a simple heuristic: 
    # i.e., how many mondays do we have in this month?
    day_of_week_mean = 30 / 7 # 4.285714285714286
    # TODO: This is a quick/gross approximation.  Programmatically get an actual count day of week for *this* month.
    
    lat = round( lat_full, rounding_places )
    lon = round( lon_full, rounding_places )
    
    # create subqueries
    trips_by_day  = trips.pickup_day_of_week == day
    trips_by_hour = trips.pickup_hour == hour
    lat_min = lat - margin
    lat_max = lat + margin
    lon_min = lon - margin
    lon_max = lon + margin
    trips_lat_min = trips.pickup_latitude_bin_2 >= lat_min
    trips_lat_max = trips.pickup_latitude_bin_2 <= lat_max
    trips_lon_min = trips.pickup_longitude_bin_2 >= lon_min
    trips_lon_max = trips.pickup_longitude_bin_2 <= lon_max
    
    # Intersection of subqueries
    candidates = trips[ ( ( trips_by_day ) & ( trips_by_hour ) & ( trips_lat_min ) & ( trips_lat_max ) & ( trips_lon_min ) & ( trips_lon_min ) ) ].copy()
    
    # stash these values for port-simulation analysis
    candidates[ "callers_lat" ] = lat_full
    candidates[ "callers_lon" ] = lon_full
    candidates[ "callers_day" ] = day
    candidates[ "callers_hour" ] = hour
    
    # calculate how many pickups per hour for this day of week, given that we're looking at a month's worth
    # of day(s), i.e., how many Tuesdays are there in this month?  30 / 7
    candidates_count = len( candidates )
    # this gives us mean pickups per hour in this candidate set...
    candidates[ "pickups_per_hour" ] = candidates_count / day_of_week_mean
    #...and thus, a mean wait time: 60 mins per hour / how many mean pickups occur in this hour of day?
    candidates[ "pickup_mean_wait_time_mins" ] = 60 / candidates.pickups_per_hour 
    
    return candidates

# %% [markdown]
# ### Quick Test of get_taxis_by_pickups(...)

# %%
day = 0
hour = 0
lat_full = 40.5773838891
lon_full = -73.9788593716

# lat = round( lat_full, 2 )
# lon = round( lon_full, 2 )

in_this_quad = get_taxis_by_pickups( day, hour, lat_full, lon_full, 2, 0.01 )
in_this_quad
# Out:
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 290928         -73.980988        40.575558         -73.978432
# 291384         -73.932617        40.584049         -73.905602
# 291650         -73.981422        40.577431         -74.033134
# 291761         -73.981224        40.575764         -74.026817
# 292662         -73.981819        40.577023         -73.952812
# 292913         -73.978577        40.575581         -73.981323
# 293103         -73.981499        40.576031         -73.977539
# 293182         -73.943581        40.583920         -73.953896
# 646639         -73.981712        40.576748         -73.985504
# 646673         -73.981491        40.576538         -74.023529
# 997186         -73.994011        40.575554         -73.994034
# 997570         -73.981613        40.576736         -73.940132
# 997599         -73.981400        40.576488         -73.976822
# 998388         -73.981400        40.576420         -73.956299
# 998400         -73.981544        40.575481         -73.956177
# 1327481        -73.979790        40.579346         -73.939537
# 1327803        -73.994461        40.575527         -73.981880
#
#          dropoff_latitude  trip_distance  trip_duration_mins  \
# 290928          40.575394           0.16            0.883333
# 291384          40.623772           5.04           12.450000
# 291650          40.625690           7.64           17.650000
# 291761          40.620869           4.93           11.333333
# 292662          40.695019          16.34           34.650000
# 292913          40.576786           3.24           18.233333
# 293103          40.606960           2.80           13.583333
# 293182          40.639648           3.90           12.283333
# 646639          40.598392           1.51            5.583333
# 646673          40.634754           7.30           15.766667
# 997186          40.575546           0.00            1.016667
# 997570          40.585163           2.53            7.283333
# 997599          40.608269           2.95           24.466667
# 998388          40.587765           2.00            5.766667
# 998400          40.675522           8.30           30.866667
# 1327481         40.583988           3.01           11.000000
# 1327803         40.576763           1.47           33.550000
#
#          pickup_day_of_week  pickup_day  pickup_hour  pickup_minute  \
# 290928                    0           7            0              4
# 291384                    0           7            0             15
# 291650                    0           7            0             18
# 291761                    0           7            0             26
# 292662                    0           7            0             29
# 292913                    0           7            0             49
# 293103                    0           7            0             39
# 293182                    0           7            0             33
# 646639                    0          14            0             30
# 646673                    0          14            0             37
# 997186                    0          21            0             11
# 997570                    0          21            0             27
# 997599                    0          21            0             15
# 998388                    0          21            0             35
# 998400                    0          21            0             32
# 1327481                   0          28            0              6
# 1327803                   0          28            0             17
#
#                     ...              pickup_latitude_bin_1  \
# 290928              ...                               40.6
# 291384              ...                               40.6
# 291650              ...                               40.6
# 291761              ...                               40.6
# 292662              ...                               40.6
# 292913              ...                               40.6
# 293103              ...                               40.6
# 293182              ...                               40.6
# 646639              ...                               40.6
# 646673              ...                               40.6
# 997186              ...                               40.6
# 997570              ...                               40.6
# 997599              ...                               40.6
# 998388              ...                               40.6
# 998400              ...                               40.6
# 1327481             ...                               40.6
# 1327803             ...                               40.6
#
#          pickup_latitude_bin_2  pickup_longitude_bin_1  \
# 290928                   40.58                   -74.0
# 291384                   40.58                   -73.9
# 291650                   40.58                   -74.0
# 291761                   40.58                   -74.0
# 292662                   40.58                   -74.0
# 292913                   40.58                   -74.0
# 293103                   40.58                   -74.0
# 293182                   40.58                   -73.9
# 646639                   40.58                   -74.0
# 646673                   40.58                   -74.0
# 997186                   40.58                   -74.0
# 997570                   40.58                   -74.0
# 997599                   40.58                   -74.0
# 998388                   40.58                   -74.0
# 998400                   40.58                   -74.0
# 1327481                  40.58                   -74.0
# 1327803                  40.58                   -74.0
#
#          pickup_longitude_bin_2  callers_lat  callers_lon  callers_day  \
# 290928                   -73.98    40.577384   -73.978859            0
# 291384                   -73.93    40.577384   -73.978859            0
# 291650                   -73.98    40.577384   -73.978859            0
# 291761                   -73.98    40.577384   -73.978859            0
# 292662                   -73.98    40.577384   -73.978859            0
# 292913                   -73.98    40.577384   -73.978859            0
# 293103                   -73.98    40.577384   -73.978859            0
# 293182                   -73.94    40.577384   -73.978859            0
# 646639                   -73.98    40.577384   -73.978859            0
# 646673                   -73.98    40.577384   -73.978859            0
# 997186                   -73.99    40.577384   -73.978859            0
# 997570                   -73.98    40.577384   -73.978859            0
# 997599                   -73.98    40.577384   -73.978859            0
# 998388                   -73.98    40.577384   -73.978859            0
# 998400                   -73.98    40.577384   -73.978859            0
# 1327481                  -73.98    40.577384   -73.978859            0
# 1327803                  -73.99    40.577384   -73.978859            0
#
#          callers_hour  pickups_per_hour  pickup_mean_wait_time_mins
# 290928              0          3.966667                    15.12605
# 291384              0          3.966667                    15.12605
# 291650              0          3.966667                    15.12605
# 291761              0          3.966667                    15.12605
# 292662              0          3.966667                    15.12605
# 292913              0          3.966667                    15.12605
# 293103              0          3.966667                    15.12605
# 293182              0          3.966667                    15.12605
# 646639              0          3.966667                    15.12605
# 646673              0          3.966667                    15.12605
# 997186              0          3.966667                    15.12605
# 997570              0          3.966667                    15.12605
# 997599              0          3.966667                    15.12605
# 998388              0          3.966667                    15.12605
# 998400              0          3.966667                    15.12605
# 1327481             0          3.966667                    15.12605
# 1327803             0          3.966667                    15.12605
#
# [17 rows x 27 columns]

# %%
def get_wait_time( row ):
    
    from_point = ( row.callers_lat, row.callers_lon )
    to_point = ( row.pickup_latitude, row.pickup_longitude )
    
    return get_time_to_pickup( row.callers_day, row.callers_hour, from_point, to_point, debug=False )

# %% [markdown]
# ## Help Function: Get Delta Between Two Bearings

# %%
# https://stackoverflow.com/questions/45659723/calculate-the-difference-between-two-compass-headings-python
def get_bearing_delta( init, final ):

    diff = final - init
    abs_diff = abs( diff )

    delta = 0
    if abs_diff == 180:
        delta = abs_diff
    elif abs_diff < 180:
        delta = diff
    elif final > init:
        delta = abs_diff - 360
    else:
        delta = 360 - abs_diff

    return delta

print("init -- final -- diff")
print("360 -- 1 -- {}".format(get_bearing_delta(360, 1)))
print("50 -- 60 -- {}".format(get_bearing_delta(50, 60)))
print("1 -- 360 -- {}".format(get_bearing_delta(1, 360)))
# Out:
# init -- final -- diff
# 360 -- 1 -- 1
# 50 -- 60 -- 10
# 1 -- 360 -- -1

# %%
# wrapper for bearings delta above
def get_bearing_delta_wrapper( row ):
    
    me = row.my_bearing
    taxi = row.pickup_bearing 
    
    # return the abs value, don't care about directionality
    return abs( get_bearing_delta( me, taxi ) )

# %% [markdown]
# ## Build Get Candidates Near Me Function

# %%
def get_candidate_list( day, hour, my_lat, my_lon, my_bearing, rounding_places=2, search_margin=0.03, max_delta=90, max_wait_mins=10 ):

    """
    Takes the preliminary results from 'get_taxis_by_pickups(...)' and further filters it by bearing and wait times
    TODO: Merge this and 'get_taxis_by_pickups(...)' into one function.
    """
    
    taxis_near_me = get_taxis_by_pickups( day, hour, my_lat, my_lon, rounding_places, search_margin )

    if len( taxis_near_me ) == 0:
        return None
    
    taxis_near_me[ "pickup_time_between_pickups_mins" ] = taxis_near_me.apply( get_wait_time, axis=1 )
    taxis_near_me[ "pickup_total_wait_mins" ] = taxis_near_me.pickup_mean_wait_time_mins + taxis_near_me.pickup_time_between_pickups_mins
    taxis_near_me.sort_values( by="pickup_total_wait_mins", inplace=True )

    quad_summary = taxis_near_me[ [ "pickup_mean_wait_time_mins", "pickup_time_between_pickups_mins", "pickup_total_wait_mins", "pickup_bearing" ] ].copy()
    quad_summary[ "day" ] = day
    quad_summary[ "hour" ] = hour
    quad_summary[ "my_bearing" ] = my_bearing
    
    # D'oh! This doesn't work, simpleton! :-(
    #quad_summary[ "delta" ] = abs( my_bearing - quad_summary.pickup_bearing )
    quad_summary[ "delta" ] = quad_summary.apply( get_bearing_delta_wrapper, axis=1 )
        
    quad_summary[ "my_lat" ] = my_lat
    quad_summary[ "my_lon" ] = my_lon
    quad_summary[ "hash" ] = hashlib.md5( ( str( my_lat ) + str( my_lon ) + str( my_bearing ) ).encode() ).hexdigest()
    
    quad_summary.columns = [ "day", "hour", "mean_wait_mins", "distance_mins", "total_mins", "taxi_bearing", "my_bearing", "delta", "my_lat", "my_lon", "hash" ]

    quad_summary_finalists = quad_summary[ ( quad_summary.delta <= max_delta ) & ( quad_summary.total_mins <= max_wait_mins ) ].copy()
    quad_summary_finalists.sort_values( by="delta", inplace=True )
    
    return quad_summary_finalists

# %% [markdown]
# ## Build Pickup Bins List for Simulation

# %%
pickup_points = trips[ [ "pickup_latitude_bin_2", "pickup_longitude_bin_2" ] ].copy()
pickup_points.sort_values( by=[ "pickup_latitude_bin_2", "pickup_longitude_bin_2" ], inplace=True )
print( len( pickup_points ) )
# we don't want ~1.5M pickup points, we want...
pickup_points_unique = pickup_points.drop_duplicates()
pickup_points_list = list( pickup_points_unique.itertuples( index=False, name=None ) )
#... 998 of them?
print( len( pickup_points_list ) )

# # grab a 10% sample to check out parallel processing
# # subsample: https://stackoverflow.com/questions/6482889/get-random-sample-from-list-while-maintaining-ordering-of-items
# sample_size = int( len( pickup_points_list ) * 0.1 )
# pickup_points_list = [ pickup_points_list[i] for i in sorted( random.sample( range( len( pickup_points_list ) ), sample_size ) ) ]
# print( len( pickup_points_list ) )

print( pickup_points_list[ 0:4 ] )
# randomize so that one core doesn't get the densest lat/lon bin
random.shuffle( pickup_points_list )
print( pickup_points_list[ 0:4 ] )

# Now useless speculation!
# seconds_per_pair = 0.2 # previous performance
# hours_to_process_uniques = len( pickup_points_list ) * seconds_per_pair * 7 * 24 / 60 / 60 / 7
# print( "     unique lat/lon coordinates", pickup_points_unique.shape[ 0 ] )
# print( "    sampled lat/lon coordinates", len( pickup_points_list ) )
# print( "  hours_to_process_uniques FAST", hours_to_process_uniques )
# print( "  hours_to_process_uniques SLOW", hours_to_process_uniques * 7 )
# Out:
# 1455831
# 988
# [(39.36, -74.44), (40.17, -74.18), (40.45, -74.29), (40.5, -74.45)]
# [(40.76, -73.7), (40.89, -73.63), (40.85, -73.98), (40.73, -73.6)]

# %% [markdown]
# ## Create Pickup Bin Chunks for Parallel Processing
#
# Chunks = The number of cores available for processing

# %%
###################################################################################################
# I've got 12 available, but I want to leave 2 free for other things while I wait
###################################################################################################
chunks = 10

records = len( pickup_points_list )
chunk_size = int( records / chunks )
print( "records", records )
print( "chunk_size", chunk_size )

chunks_list = []

for ith in range( 0, chunks ):
    
    start = ith * chunk_size
    
    if ith == chunks - 1:
        end = records
    else:
        end = start + chunk_size
    
    chunk = pickup_points_list[ start:end ]
    chunks_list.append( chunk )
    
    print( ith, start, end, ( end - start ), len( chunk ) )
    
print( len( chunks_list ) )
# Out:
# records 988
# chunk_size 98
# 0 0 98 98 98
# 1 98 196 98 98
# 2 196 294 98 98
# 3 294 392 98 98
# 4 392 490 98 98
# 5 490 588 98 98
# 6 588 686 98 98
# 7 686 784 98 98
# 8 784 882 98 98
# 9 882 988 106 106
# 10

# %% [markdown]
# ## Declare Target Function to Run in Parallel Processes

# %%
###################################################################################################
# declare where we're dumping results
###################################################################################################
#directory_name = "uber-simulation-10-percent"
directory_name = "uber-simulation"
def process_trips_in_chunk( data_grp, pickup_points_chunk ):
    
    # for calculating ETA
    points_count = len( pickup_points_chunk )

    # get thread name from multiprocessing library
    thread_name = current_process().name
    count = 1
    start_time = get_time()
    
    # search parameters
    rounding_places = 2
    bin_width = 0.01
    search_margin_degs = 0.01
    max_wait_mins = 10
    max_delta = 90

    results_buffer = []
    errors_buffer = []

    for pickup_point in pickup_points_chunk:

        binned_lat, binned_lon = pickup_point
        
        for day in range( 7 ):
            
            for hour in range( 24 ):
                
                # get random bearing every time
                my_bearing = random.uniform( 0.0, 360.0 )
                # add a bit if randomicity to current lat/lon
                random_lat = random.uniform( binned_lat - bin_width / 2, binned_lat + bin_width / 2 )
                random_lon = random.uniform( binned_lon - bin_width / 2, binned_lon + bin_width / 2 )
                
                # get pared down list of taxis near me, closest to my bearing
                results = pd.DataFrame()
                results = get_candidate_list( day, hour, random_lat, random_lon, my_bearing, rounding_places, search_margin_degs, max_delta, max_wait_mins )
                # can't do "results == None"! http://thomas-cokelaer.info/blog/2014/06/pandas-how-to-compare-dataframe-with-none/
                if results is None:
                    errors_buffer.append( str( day ) + "," + str( hour ) + "," + str( binned_lat ) + "," + str( binned_lon ) + "," + str( my_bearing ) + "," + str( random_lat ) + "," + str( random_lon ) )
                else:
                    results_buffer.append( results )

        seconds = time.time() - start_time
        points_per_second = ( count * 1.0 ) / seconds
        percent_completed = ( ( count * 1.0 ) / points_count ) * 100.0
        points_remaining = points_count - count
        minutes_remaining = ( points_remaining / points_per_second ) / 60.0
        print( "[%s] [%d] of [%d] points, running [%f] minutes @ [%d] points/s, [%f]p/c complete, ETA [%f] minutes" % ( thread_name, count, points_count, seconds / 60, points_per_second, percent_completed, minutes_remaining ) )
        count += 1
        
    # write results
    results_df = pd.concat( results_buffer )
    file_name = "data/" + directory_name + "/points-" + thread_name.lower() + ".csv"
    results_df.to_csv( file_name, index=False )
    print( "[%s] DONE! Wrote [%d] points to [%s]" % ( thread_name, count - 1, file_name ) )
     
    # write errors: file
    file_name = "data/" + directory_name + "/points-" + thread_name.lower() + "-errors.csv"
    with open( file_name, 'w' ) as file:
        for line in errors_buffer:
            file.write( line )
            file.write( '\n' )

# %% [markdown]
# ## Start n Separate Processes
# Probably 10 cores, leaving 2 cores free so I can do other things while this chews its way through data.
#
# Previous full run on 2018.05.07 @ 12:32pm
# Time to process all chunks: [24.953591577212016] minutes

# %%
# from https://www.blog.pythonlibrary.org/2016/08/02/python-201-a-multiprocessing-tutorial/
# THIS IS MULTI-PROCESS, *NOT* MULTITHREADED! Uses 100% of 10 cores 
start_time = get_time()    
procs = []

for ith in range( 0, chunks ):
    
    proc = Process( target=process_trips_in_chunk, args=( trips, chunks_list[ ith ] ) )
    procs.append( proc )
    proc.start()

for proc in procs:
    proc.join()
    print( "Process on this core: Done!" )
    
end_time = get_time()
print ( "Time to process all chunks: [%s] minutes" % ( str( ( end_time - start_time ) / 60 ) ) )
# Out:
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# 2018.05.09 13:42
# [Process-39] [1] of [98] points, running [0.079395] minutes @ [0] points/s, [1.020408]p/c complete, ETA [7.701349] minutes
# [Process-35] [1] of [98] points, running [0.099739] minutes @ [0] points/s, [1.020408]p/c complete, ETA [9.674713] minutes
# [Process-33] [1] of [98] points, running [0.105934] minutes @ [0] points/s, [1.020408]p/c complete, ETA [10.275627] minutes
# [Process-31] [1] of [98] points, running [0.109611] minutes @ [0] points/s, [1.020408]p/c complete, ETA [10.632280] minutes
# [Process-34] [1] of [98] points, running [0.117594] minutes @ [0] points/s, [1.020408]p/c complete, ETA [11.406607] minutes
# [Process-32] [1] of [98] points, running [0.122543] minutes @ [0] points/s, [1.020408]p/c complete, ETA [11.886632] minutes
# [Process-40] [1] of [106] points, running [0.151298] minutes @ [0] points/s, [0.943396]p/c complete, ETA [15.886327] minutes
# [Process-35] [2] of [98] points, running [0.184016] minutes @ [0] points/s, [2.040816]p/c complete, ETA [8.832787] minutes
# [Process-31] [2] of [98] points, running [0.199636] minutes @ [0] points/s, [2.040816]p/c complete, ETA [9.582510] minutes
# [Process-34] [2] of [98] points, running [0.206315] minutes @ [0] points/s, [2.040816]p/c complete, ETA [9.903135] minutes
# [Process-39] [2] of [98] points, running [0.215576] minutes @ [0] points/s, [2.040816]p/c complete, ETA [10.347667] minutes
# [Process-33] [2] of [98] points, running [0.220417] minutes @ [0] points/s, [2.040816]p/c complete, ETA [10.579994] minutes
# [Process-32] [2] of [98] points, running [0.239536] minutes @ [0] points/s, [2.040816]p/c complete, ETA [11.497749] minutes
# [Process-35] [3] of [98] points, running [0.248839] minutes @ [0] points/s, [3.061224]p/c complete, ETA [7.879907] minutes
# [Process-36] [1] of [98] points, running [0.251733] minutes @ [0] points/s, [1.020408]p/c complete, ETA [24.418112] minutes
# [Process-32] [3] of [98] points, running [0.303801] minutes @ [0] points/s, [3.061224]p/c complete, ETA [9.620359] minutes
# [Process-34] [3] of [98] points, running [0.307003] minutes @ [0] points/s, [3.061224]p/c complete, ETA [9.721746] minutes
# [Process-35] [4] of [98] points, running [0.310811] minutes @ [0] points/s, [4.081633]p/c complete, ETA [7.304049] minutes
# [Process-34] [4] of [98] points, running [0.366455] minutes @ [0] points/s, [4.081633]p/c complete, ETA [8.611693] minutes
# [Process-39] [3] of [98] points, running [0.373393] minutes @ [0] points/s, [3.061224]p/c complete, ETA [11.824096] minutes
# [Process-36] [2] of [98] points, running [0.374631] minutes @ [0] points/s, [2.040816]p/c complete, ETA [17.982277] minutes
# [Process-36] [3] of [98] points, running [0.421592] minutes @ [0] points/s, [3.061224]p/c complete, ETA [13.350405] minutes
# [Process-39] [4] of [98] points, running [0.421950] minutes @ [0] points/s, [4.081633]p/c complete, ETA [9.915815] minutes
# [Process-38] [1] of [98] points, running [0.426239] minutes @ [0] points/s, [1.020408]p/c complete, ETA [41.345209] minutes
# [Process-36] [4] of [98] points, running [0.465891] minutes @ [0] points/s, [4.081633]p/c complete, ETA [10.948428] minutes
# [Process-38] [2] of [98] points, running [0.505135] minutes @ [0] points/s, [2.040816]p/c complete, ETA [24.246502] minutes
# [Process-36] [5] of [98] points, running [0.520554] minutes @ [0] points/s, [5.102041]p/c complete, ETA [9.682306] minutes
# [Process-37] [1] of [98] points, running [0.546227] minutes @ [0] points/s, [1.020408]p/c complete, ETA [52.984037] minutes
# [Process-31] [3] of [98] points, running [0.551120] minutes @ [0] points/s, [3.061224]p/c complete, ETA [17.452130] minutes
# [Process-37] [2] of [98] points, running [0.594898] minutes @ [0] points/s, [2.040816]p/c complete, ETA [28.555103] minutes
# [Process-36] [6] of [98] points, running [0.598794] minutes @ [0] points/s, [6.122449]p/c complete, ETA [9.181515] minutes
# [Process-31] [4] of [98] points, running [0.604505] minutes @ [0] points/s, [4.081633]p/c complete, ETA [14.205860] minutes
# [Process-36] [7] of [98] points, running [0.645015] minutes @ [0] points/s, [7.142857]p/c complete, ETA [8.385201] minutes
# [Process-39] [5] of [98] points, running [0.651188] minutes @ [0] points/s, [5.102041]p/c complete, ETA [12.112106] minutes
# [Process-37] [3] of [98] points, running [0.664282] minutes @ [0] points/s, [3.061224]p/c complete, ETA [21.035602] minutes
# [Process-36] [8] of [98] points, running [0.684898] minutes @ [0] points/s, [8.163265]p/c complete, ETA [7.705104] minutes
# [Process-36] [9] of [98] points, running [0.736158] minutes @ [0] points/s, [9.183673]p/c complete, ETA [7.279783] minutes
# [Process-37] [4] of [98] points, running [0.742387] minutes @ [0] points/s, [4.081633]p/c complete, ETA [17.446090] minutes
# [Process-36] [10] of [98] points, running [0.806353] minutes @ [0] points/s, [10.204082]p/c complete, ETA [7.095907] minutes
# [Process-37] [5] of [98] points, running [0.837379] minutes @ [0] points/s, [5.102041]p/c complete, ETA [15.575241] minutes
# [Process-36] [11] of [98] points, running [0.860411] minutes @ [0] points/s, [11.224490]p/c complete, ETA [6.805068] minutes
# [Process-37] [6] of [98] points, running [0.874238] minutes @ [0] points/s, [6.122449]p/c complete, ETA [13.404987] minutes
# [Process-31] [5] of [98] points, running [1.076253] minutes @ [0] points/s, [5.102041]p/c complete, ETA [20.018302] minutes
# [Process-33] [3] of [98] points, running [1.090389] minutes @ [0] points/s, [3.061224]p/c complete, ETA [34.528986] minutes
# [Process-38] [3] of [98] points, running [1.123468] minutes @ [0] points/s, [3.061224]p/c complete, ETA [35.576477] minutes
# [Process-31] [6] of [98] points, running [1.128189] minutes @ [0] points/s, [6.122449]p/c complete, ETA [17.298892] minutes
# [Process-38] [4] of [98] points, running [1.175997] minutes @ [0] points/s, [4.081633]p/c complete, ETA [27.635939] minutes
# [Process-33] [4] of [98] points, running [1.189017] minutes @ [0] points/s, [4.081633]p/c complete, ETA [27.941890] minutes
# [Process-39] [6] of [98] points, running [1.192967] minutes @ [0] points/s, [6.122449]p/c complete, ETA [18.292161] minutes
# [Process-32] [4] of [98] points, running [1.227076] minutes @ [0] points/s, [4.081633]p/c complete, ETA [28.836277] minutes
# [Process-38] [5] of [98] points, running [1.233940] minutes @ [0] points/s, [5.102041]p/c complete, ETA [22.951276] minutes
# [Process-31] [7] of [98] points, running [1.243540] minutes @ [0] points/s, [7.142857]p/c complete, ETA [16.166024] minutes
# [Process-40] [2] of [106] points, running [1.249387] minutes @ [0] points/s, [1.886792]p/c complete, ETA [64.968115] minutes
# [Process-39] [7] of [98] points, running [1.260613] minutes @ [0] points/s, [7.142857]p/c complete, ETA [16.387970] minutes
# [Process-37] [7] of [98] points, running [1.263105] minutes @ [0] points/s, [7.142857]p/c complete, ETA [16.420371] minutes
# [Process-31] [8] of [98] points, running [1.309925] minutes @ [0] points/s, [8.163265]p/c complete, ETA [14.736657] minutes
# [Process-40] [3] of [106] points, running [1.309438] minutes @ [0] points/s, [2.830189]p/c complete, ETA [44.957355] minutes
# [Process-37] [8] of [98] points, running [1.348233] minutes @ [0] points/s, [8.163265]p/c complete, ETA [15.167617] minutes
# [Process-39] [8] of [98] points, running [1.358469] minutes @ [0] points/s, [8.163265]p/c complete, ETA [15.282779] minutes
# [Process-31] [9] of [98] points, running [1.366434] minutes @ [0] points/s, [9.183673]p/c complete, ETA [13.512510] minutes
# [Process-40] [4] of [106] points, running [1.403483] minutes @ [0] points/s, [3.773585]p/c complete, ETA [35.788805] minutes
# [Process-35] [5] of [98] points, running [1.410401] minutes @ [0] points/s, [5.102041]p/c complete, ETA [26.233456] minutes
# [Process-37] [9] of [98] points, running [1.418631] minutes @ [0] points/s, [9.183673]p/c complete, ETA [14.028682] minutes
# [Process-39] [9] of [98] points, running [1.426952] minutes @ [0] points/s, [9.183673]p/c complete, ETA [14.110974] minutes
# [Process-38] [6] of [98] points, running [1.428520] minutes @ [0] points/s, [6.122449]p/c complete, ETA [21.903979] minutes
# [Process-35] [6] of [98] points, running [1.474302] minutes @ [0] points/s, [6.122449]p/c complete, ETA [22.605968] minutes
# [Process-37] [10] of [98] points, running [1.482491] minutes @ [0] points/s, [10.204082]p/c complete, ETA [13.045920] minutes
# [Process-38] [7] of [98] points, running [1.502877] minutes @ [0] points/s, [7.142857]p/c complete, ETA [19.537405] minutes
# [Process-39] [10] of [98] points, running [1.513926] minutes @ [0] points/s, [10.204082]p/c complete, ETA [13.322553] minutes
# [Process-37] [11] of [98] points, running [1.528476] minutes @ [0] points/s, [11.224490]p/c complete, ETA [12.088856] minutes
# [Process-39] [11] of [98] points, running [1.567317] minutes @ [0] points/s, [11.224490]p/c complete, ETA [12.396049] minutes
# [Process-38] [8] of [98] points, running [1.592990] minutes @ [0] points/s, [8.163265]p/c complete, ETA [17.921140] minutes
# [Process-37] [12] of [98] points, running [1.603997] minutes @ [0] points/s, [12.244898]p/c complete, ETA [11.495312] minutes
# [Process-39] [12] of [98] points, running [1.623085] minutes @ [0] points/s, [12.244898]p/c complete, ETA [11.632110] minutes
# [Process-40] [5] of [106] points, running [1.625145] minutes @ [0] points/s, [4.716981]p/c complete, ETA [32.827919] minutes
# [Process-34] [5] of [98] points, running [1.630080] minutes @ [0] points/s, [5.102041]p/c complete, ETA [30.319495] minutes
# [Process-38] [9] of [98] points, running [1.677509] minutes @ [0] points/s, [9.183673]p/c complete, ETA [16.588701] minutes
# [Process-39] [13] of [98] points, running [1.681770] minutes @ [0] points/s, [13.265306]p/c complete, ETA [10.996186] minutes
# [Process-37] [13] of [98] points, running [1.693965] minutes @ [0] points/s, [13.265306]p/c complete, ETA [11.075925] minutes
# [Process-40] [6] of [106] points, running [1.702055] minutes @ [0] points/s, [5.660377]p/c complete, ETA [28.367576] minutes
# [Process-35] [7] of [98] points, running [1.710969] minutes @ [0] points/s, [7.142857]p/c complete, ETA [22.242594] minutes
# [Process-31] [10] of [98] points, running [1.727501] minutes @ [0] points/s, [10.204082]p/c complete, ETA [15.202007] minutes
# [Process-39] [14] of [98] points, running [1.746480] minutes @ [0] points/s, [14.285714]p/c complete, ETA [10.478881] minutes
# [Process-37] [14] of [98] points, running [1.749021] minutes @ [0] points/s, [14.285714]p/c complete, ETA [10.494124] minutes
# [Process-39] [15] of [98] points, running [1.818155] minutes @ [0] points/s, [15.306122]p/c complete, ETA [10.060458] minutes
# [Process-36] [12] of [98] points, running [1.818744] minutes @ [0] points/s, [12.244898]p/c complete, ETA [13.034334] minutes
# [Process-36] [13] of [98] points, running [1.858993] minutes @ [0] points/s, [13.265306]p/c complete, ETA [12.154953] minutes
# [Process-36] [14] of [98] points, running [1.889762] minutes @ [0] points/s, [14.285714]p/c complete, ETA [11.338570] minutes
# [Process-37] [15] of [98] points, running [2.069605] minutes @ [0] points/s, [15.306122]p/c complete, ETA [11.451814] minutes
# [Process-37] [16] of [98] points, running [2.131526] minutes @ [0] points/s, [16.326531]p/c complete, ETA [10.924072] minutes
# [Process-37] [17] of [98] points, running [2.201409] minutes @ [0] points/s, [17.346939]p/c complete, ETA [10.489065] minutes
# [Process-34] [6] of [98] points, running [2.235152] minutes @ [0] points/s, [6.122449]p/c complete, ETA [34.272337] minutes
# [Process-37] [18] of [98] points, running [2.260835] minutes @ [0] points/s, [18.367347]p/c complete, ETA [10.048157] minutes
# [Process-34] [7] of [98] points, running [2.443013] minutes @ [0] points/s, [7.142857]p/c complete, ETA [31.759167] minutes
# [Process-39] [16] of [98] points, running [2.478804] minutes @ [0] points/s, [16.326531]p/c complete, ETA [12.703873] minutes
# [Process-31] [11] of [98] points, running [2.496973] minutes @ [0] points/s, [11.224490]p/c complete, ETA [19.748788] minutes
# [Process-34] [8] of [98] points, running [2.499448] minutes @ [0] points/s, [8.163265]p/c complete, ETA [28.118793] minutes
# [Process-33] [5] of [98] points, running [2.546030] minutes @ [0] points/s, [5.102041]p/c complete, ETA [47.356154] minutes
# [Process-34] [9] of [98] points, running [2.547549] minutes @ [0] points/s, [9.183673]p/c complete, ETA [25.192433] minutes
# [Process-38] [10] of [98] points, running [2.570534] minutes @ [0] points/s, [10.204082]p/c complete, ETA [22.620702] minutes
# [Process-33] [6] of [98] points, running [2.613483] minutes @ [0] points/s, [6.122449]p/c complete, ETA [40.073413] minutes
# [Process-32] [5] of [98] points, running [2.646251] minutes @ [0] points/s, [5.102041]p/c complete, ETA [49.220270] minutes
# [Process-32] [6] of [98] points, running [2.682853] minutes @ [0] points/s, [6.122449]p/c complete, ETA [41.137077] minutes
# [Process-33] [7] of [98] points, running [2.690675] minutes @ [0] points/s, [7.142857]p/c complete, ETA [34.978771] minutes
# [Process-32] [7] of [98] points, running [2.719731] minutes @ [0] points/s, [7.142857]p/c complete, ETA [35.356507] minutes
# [Process-33] [8] of [98] points, running [2.741676] minutes @ [0] points/s, [8.163265]p/c complete, ETA [30.843855] minutes
# [Process-36] [15] of [98] points, running [2.762190] minutes @ [0] points/s, [15.306122]p/c complete, ETA [15.284121] minutes
# [Process-32] [8] of [98] points, running [2.765494] minutes @ [0] points/s, [8.163265]p/c complete, ETA [31.111808] minutes
# [Process-33] [9] of [98] points, running [2.798410] minutes @ [0] points/s, [9.183673]p/c complete, ETA [27.673163] minutes
# [Process-38] [11] of [98] points, running [2.799842] minutes @ [0] points/s, [11.224490]p/c complete, ETA [22.144205] minutes
# [Process-37] [19] of [98] points, running [2.810314] minutes @ [0] points/s, [19.387755]p/c complete, ETA [11.684990] minutes
# [Process-36] [16] of [98] points, running [2.815243] minutes @ [0] points/s, [16.326531]p/c complete, ETA [14.428120] minutes
# [Process-37] [20] of [98] points, running [2.862349] minutes @ [0] points/s, [20.408163]p/c complete, ETA [11.163162] minutes
# [Process-32] [9] of [98] points, running [2.871878] minutes @ [0] points/s, [9.183673]p/c complete, ETA [28.399683] minutes
# [Process-38] [12] of [98] points, running [2.871486] minutes @ [0] points/s, [12.244898]p/c complete, ETA [20.578982] minutes
# [Process-34] [10] of [98] points, running [2.900723] minutes @ [0] points/s, [10.204082]p/c complete, ETA [25.526361] minutes
# [Process-38] [13] of [98] points, running [2.917615] minutes @ [0] points/s, [13.265306]p/c complete, ETA [19.076717] minutes
# [Process-34] [11] of [98] points, running [2.962634] minutes @ [0] points/s, [11.224490]p/c complete, ETA [23.431739] minutes
# [Process-38] [14] of [98] points, running [2.995008] minutes @ [0] points/s, [14.285714]p/c complete, ETA [17.970049] minutes
# [Process-40] [7] of [106] points, running [2.994968] minutes @ [0] points/s, [6.603774]p/c complete, ETA [42.357404] minutes
# [Process-36] [17] of [98] points, running [3.036061] minutes @ [0] points/s, [17.346939]p/c complete, ETA [14.465940] minutes
# [Process-40] [8] of [106] points, running [3.040445] minutes @ [0] points/s, [7.547170]p/c complete, ETA [37.245447] minutes
# [Process-34] [12] of [98] points, running [3.042651] minutes @ [0] points/s, [12.244898]p/c complete, ETA [21.805666] minutes
# [Process-33] [10] of [98] points, running [3.050640] minutes @ [0] points/s, [10.204082]p/c complete, ETA [26.845635] minutes
# [Process-35] [8] of [98] points, running [3.069477] minutes @ [0] points/s, [8.163265]p/c complete, ETA [34.531611] minutes
# [Process-33] [11] of [98] points, running [3.095958] minutes @ [0] points/s, [11.224490]p/c complete, ETA [24.486213] minutes
# [Process-34] [13] of [98] points, running [3.119502] minutes @ [0] points/s, [13.265306]p/c complete, ETA [20.396741] minutes
# [Process-38] [15] of [98] points, running [3.122517] minutes @ [0] points/s, [15.306122]p/c complete, ETA [17.277925] minutes
# [Process-35] [9] of [98] points, running [3.160630] minutes @ [0] points/s, [9.183673]p/c complete, ETA [31.255122] minutes
# [Process-33] [12] of [98] points, running [3.174288] minutes @ [0] points/s, [12.244898]p/c complete, ETA [22.749067] minutes
# [Process-38] [16] of [98] points, running [3.177448] minutes @ [0] points/s, [16.326531]p/c complete, ETA [16.284423] minutes
# [Process-37] [21] of [98] points, running [3.181235] minutes @ [0] points/s, [21.428571]p/c complete, ETA [11.664527] minutes
# [Process-34] [14] of [98] points, running [3.200410] minutes @ [0] points/s, [14.285714]p/c complete, ETA [19.202458] minutes
# [Process-40] [9] of [106] points, running [3.223108] minutes @ [0] points/s, [8.490566]p/c complete, ETA [34.737947] minutes
# [Process-35] [10] of [98] points, running [3.248769] minutes @ [0] points/s, [10.204082]p/c complete, ETA [28.589169] minutes
# [Process-39] [17] of [98] points, running [3.249650] minutes @ [0] points/s, [17.346939]p/c complete, ETA [15.483627] minutes
# [Process-37] [22] of [98] points, running [3.283495] minutes @ [0] points/s, [22.448980]p/c complete, ETA [11.342981] minutes
# [Process-31] [12] of [98] points, running [3.286621] minutes @ [0] points/s, [12.244898]p/c complete, ETA [23.554116] minutes
# [Process-40] [10] of [106] points, running [3.297353] minutes @ [0] points/s, [9.433962]p/c complete, ETA [31.654585] minutes
# [Process-39] [18] of [98] points, running [3.313514] minutes @ [0] points/s, [18.367347]p/c complete, ETA [14.726731] minutes
# [Process-40] [11] of [106] points, running [3.348861] minutes @ [0] points/s, [10.377358]p/c complete, ETA [28.921978] minutes
# [Process-38] [17] of [98] points, running [3.357347] minutes @ [0] points/s, [17.346939]p/c complete, ETA [15.996771] minutes
# [Process-37] [23] of [98] points, running [3.362777] minutes @ [0] points/s, [23.469388]p/c complete, ETA [10.965576] minutes
# [Process-35] [11] of [98] points, running [3.432396] minutes @ [0] points/s, [11.224490]p/c complete, ETA [27.147135] minutes
# [Process-38] [18] of [98] points, running [3.441328] minutes @ [0] points/s, [18.367347]p/c complete, ETA [15.294789] minutes
# [Process-37] [24] of [98] points, running [3.494689] minutes @ [0] points/s, [24.489796]p/c complete, ETA [10.775292] minutes
# [Process-38] [19] of [98] points, running [3.507533] minutes @ [0] points/s, [19.387755]p/c complete, ETA [14.583955] minutes
# [Process-34] [15] of [98] points, running [3.583834] minutes @ [0] points/s, [15.306122]p/c complete, ETA [19.830550] minutes
# [Process-40] [12] of [106] points, running [3.613727] minutes @ [0] points/s, [11.320755]p/c complete, ETA [28.307524] minutes
# [Process-34] [16] of [98] points, running [3.622869] minutes @ [0] points/s, [16.326531]p/c complete, ETA [18.567202] minutes
# [Process-34] [17] of [98] points, running [3.657168] minutes @ [0] points/s, [17.346939]p/c complete, ETA [17.425331] minutes
# [Process-34] [18] of [98] points, running [3.695538] minutes @ [0] points/s, [18.367347]p/c complete, ETA [16.424614] minutes
# [Process-38] [20] of [98] points, running [3.699817] minutes @ [0] points/s, [20.408163]p/c complete, ETA [14.429287] minutes
# [Process-31] [13] of [98] points, running [3.768315] minutes @ [0] points/s, [13.265306]p/c complete, ETA [24.638980] minutes
# [Process-37] [25] of [98] points, running [3.803619] minutes @ [0] points/s, [25.510204]p/c complete, ETA [11.106568] minutes
# [Process-38] [21] of [98] points, running [3.808646] minutes @ [0] points/s, [21.428571]p/c complete, ETA [13.965037] minutes
# [Process-31] [14] of [98] points, running [3.810051] minutes @ [0] points/s, [14.285714]p/c complete, ETA [22.860308] minutes
# [Process-37] [26] of [98] points, running [3.853980] minutes @ [0] points/s, [26.530612]p/c complete, ETA [10.672560] minutes
# [Process-31] [15] of [98] points, running [3.876004] minutes @ [0] points/s, [15.306122]p/c complete, ETA [21.447223] minutes
# [Process-38] [22] of [98] points, running [3.878062] minutes @ [0] points/s, [22.448980]p/c complete, ETA [13.396941] minutes
# [Process-37] [27] of [98] points, running [3.901053] minutes @ [0] points/s, [27.551020]p/c complete, ETA [10.258325] minutes
# [Process-31] [16] of [98] points, running [3.920108] minutes @ [0] points/s, [16.326531]p/c complete, ETA [20.090553] minutes
# [Process-37] [28] of [98] points, running [3.963437] minutes @ [0] points/s, [28.571429]p/c complete, ETA [9.908594] minutes
# [Process-31] [17] of [98] points, running [3.967485] minutes @ [0] points/s, [17.346939]p/c complete, ETA [18.903898] minutes
# [Process-35] [12] of [98] points, running [4.006269] minutes @ [0] points/s, [12.244898]p/c complete, ETA [28.711594] minutes
# [Process-31] [18] of [98] points, running [4.024765] minutes @ [0] points/s, [18.367347]p/c complete, ETA [17.887845] minutes
# [Process-35] [13] of [98] points, running [4.061811] minutes @ [0] points/s, [13.265306]p/c complete, ETA [26.557996] minutes
# [Process-35] [14] of [98] points, running [4.107444] minutes @ [0] points/s, [14.285714]p/c complete, ETA [24.644666] minutes
# [Process-35] [15] of [98] points, running [4.146295] minutes @ [0] points/s, [15.306122]p/c complete, ETA [22.942830] minutes
# [Process-39] [19] of [98] points, running [4.149054] minutes @ [0] points/s, [19.387755]p/c complete, ETA [17.251332] minutes
# [Process-35] [16] of [98] points, running [4.186774] minutes @ [0] points/s, [16.326531]p/c complete, ETA [21.457215] minutes
# [Process-35] [17] of [98] points, running [4.227990] minutes @ [0] points/s, [17.346939]p/c complete, ETA [20.145131] minutes
# [Process-32] [10] of [98] points, running [4.253705] minutes @ [0] points/s, [10.204082]p/c complete, ETA [37.432601] minutes
# [Process-35] [18] of [98] points, running [4.285888] minutes @ [0] points/s, [18.367347]p/c complete, ETA [19.048393] minutes
# [Process-35] [19] of [98] points, running [4.331708] minutes @ [0] points/s, [19.387755]p/c complete, ETA [18.010785] minutes
# [Process-31] [19] of [98] points, running [4.337223] minutes @ [0] points/s, [19.387755]p/c complete, ETA [18.033718] minutes
# [Process-37] [29] of [98] points, running [4.348985] minutes @ [0] points/s, [29.591837]p/c complete, ETA [10.347585] minutes
# [Process-36] [18] of [98] points, running [4.360762] minutes @ [0] points/s, [18.367347]p/c complete, ETA [19.381164] minutes
# [Process-35] [20] of [98] points, running [4.387714] minutes @ [0] points/s, [20.408163]p/c complete, ETA [17.112086] minutes
# [Process-40] [13] of [106] points, running [4.389979] minutes @ [0] points/s, [12.264151]p/c complete, ETA [31.405233] minutes
# [Process-32] [11] of [98] points, running [4.415255] minutes @ [0] points/s, [11.224490]p/c complete, ETA [34.920654] minutes
# [Process-35] [21] of [98] points, running [4.424354] minutes @ [0] points/s, [21.428571]p/c complete, ETA [16.222630] minutes
# [Process-36] [19] of [98] points, running [4.488265] minutes @ [0] points/s, [19.387755]p/c complete, ETA [18.661733] minutes
# [Process-35] [22] of [98] points, running [4.504033] minutes @ [0] points/s, [22.448980]p/c complete, ETA [15.559385] minutes
# [Process-33] [13] of [98] points, running [4.533440] minutes @ [0] points/s, [13.265306]p/c complete, ETA [29.641723] minutes
# [Process-35] [23] of [98] points, running [4.547553] minutes @ [0] points/s, [23.469388]p/c complete, ETA [14.828976] minutes
# [Process-37] [30] of [98] points, running [4.569360] minutes @ [0] points/s, [30.612245]p/c complete, ETA [10.357216] minutes
# [Process-39] [20] of [98] points, running [4.608838] minutes @ [0] points/s, [20.408163]p/c complete, ETA [17.974467] minutes
# [Process-37] [31] of [98] points, running [4.620890] minutes @ [0] points/s, [31.632653]p/c complete, ETA [9.987084] minutes
# [Process-33] [14] of [98] points, running [4.636360] minutes @ [0] points/s, [14.285714]p/c complete, ETA [27.818160] minutes
# [Process-36] [20] of [98] points, running [4.649091] minutes @ [0] points/s, [20.408163]p/c complete, ETA [18.131455] minutes
# [Process-34] [19] of [98] points, running [4.661545] minutes @ [0] points/s, [19.387755]p/c complete, ETA [19.382211] minutes
# [Process-39] [21] of [98] points, running [4.662245] minutes @ [0] points/s, [21.428571]p/c complete, ETA [17.094898] minutes
# [Process-38] [23] of [98] points, running [4.671977] minutes @ [0] points/s, [23.469388]p/c complete, ETA [15.234708] minutes
# [Process-35] [24] of [98] points, running [4.677007] minutes @ [0] points/s, [24.489796]p/c complete, ETA [14.420772] minutes
# [Process-36] [21] of [98] points, running [4.703073] minutes @ [0] points/s, [21.428571]p/c complete, ETA [17.244600] minutes
# [Process-38] [24] of [98] points, running [4.727735] minutes @ [0] points/s, [24.489796]p/c complete, ETA [14.577181] minutes
# [Process-33] [15] of [98] points, running [4.756242] minutes @ [0] points/s, [15.306122]p/c complete, ETA [26.317872] minutes
# [Process-34] [20] of [98] points, running [4.775652] minutes @ [0] points/s, [20.408163]p/c complete, ETA [18.625044] minutes
# [Process-33] [16] of [98] points, running [4.802047] minutes @ [0] points/s, [16.326531]p/c complete, ETA [24.610492] minutes
# [Process-34] [21] of [98] points, running [4.835471] minutes @ [0] points/s, [21.428571]p/c complete, ETA [17.730059] minutes
# [Process-34] [22] of [98] points, running [4.890254] minutes @ [0] points/s, [22.448980]p/c complete, ETA [16.893606] minutes
# [Process-35] [25] of [98] points, running [4.894170] minutes @ [0] points/s, [25.510204]p/c complete, ETA [14.290976] minutes
# [Process-35] [26] of [98] points, running [4.944022] minutes @ [0] points/s, [26.530612]p/c complete, ETA [13.691139] minutes
# [Process-35] [27] of [98] points, running [5.090042] minutes @ [0] points/s, [27.551020]p/c complete, ETA [13.384925] minutes
# [Process-35] [28] of [98] points, running [5.141393] minutes @ [0] points/s, [28.571429]p/c complete, ETA [12.853482] minutes
# [Process-35] [29] of [98] points, running [5.204264] minutes @ [0] points/s, [29.591837]p/c complete, ETA [12.382560] minutes
# [Process-35] [30] of [98] points, running [5.247391] minutes @ [0] points/s, [30.612245]p/c complete, ETA [11.894087] minutes
# [Process-40] [14] of [106] points, running [5.289867] minutes @ [0] points/s, [13.207547]p/c complete, ETA [34.761982] minutes
# [Process-34] [23] of [98] points, running [5.309244] minutes @ [0] points/s, [23.469388]p/c complete, ETA [17.312751] minutes
# [Process-37] [32] of [98] points, running [5.322757] minutes @ [0] points/s, [32.653061]p/c complete, ETA [10.978187] minutes
# [Process-40] [15] of [106] points, running [5.329878] minutes @ [0] points/s, [14.150943]p/c complete, ETA [32.334594] minutes
# [Process-34] [24] of [98] points, running [5.350984] minutes @ [0] points/s, [24.489796]p/c complete, ETA [16.498866] minutes
# [Process-37] [33] of [98] points, running [5.375699] minutes @ [0] points/s, [33.673469]p/c complete, ETA [10.588498] minutes
# [Process-34] [25] of [98] points, running [5.389211] minutes @ [0] points/s, [25.510204]p/c complete, ETA [15.736496] minutes
# [Process-31] [20] of [98] points, running [5.403812] minutes @ [0] points/s, [20.408163]p/c complete, ETA [21.074866] minutes
# [Process-37] [34] of [98] points, running [5.444771] minutes @ [0] points/s, [34.693878]p/c complete, ETA [10.248980] minutes
# [Process-31] [21] of [98] points, running [5.463167] minutes @ [0] points/s, [21.428571]p/c complete, ETA [20.031611] minutes
# [Process-37] [35] of [98] points, running [5.487247] minutes @ [0] points/s, [35.714286]p/c complete, ETA [9.877044] minutes
# [Process-39] [22] of [98] points, running [5.523443] minutes @ [0] points/s, [22.448980]p/c complete, ETA [19.080986] minutes
# [Process-37] [36] of [98] points, running [5.539542] minutes @ [0] points/s, [36.734694]p/c complete, ETA [9.540322] minutes
# [Process-34] [26] of [98] points, running [5.541851] minutes @ [0] points/s, [26.530612]p/c complete, ETA [15.346663] minutes
# [Process-31] [22] of [98] points, running [5.554712] minutes @ [0] points/s, [22.448980]p/c complete, ETA [19.189004] minutes
# [Process-39] [23] of [98] points, running [5.570444] minutes @ [0] points/s, [23.469388]p/c complete, ETA [18.164492] minutes
# [Process-33] [17] of [98] points, running [5.579653] minutes @ [0] points/s, [17.346939]p/c complete, ETA [26.585403] minutes
# [Process-36] [22] of [98] points, running [5.585567] minutes @ [0] points/s, [22.448980]p/c complete, ETA [19.295595] minutes
# [Process-32] [12] of [98] points, running [5.605979] minutes @ [0] points/s, [12.244898]p/c complete, ETA [40.176182] minutes
# [Process-34] [27] of [98] points, running [5.618568] minutes @ [0] points/s, [27.551020]p/c complete, ETA [14.774753] minutes
# [Process-33] [18] of [98] points, running [5.644301] minutes @ [0] points/s, [18.367347]p/c complete, ETA [25.085783] minutes
# [Process-36] [23] of [98] points, running [5.663664] minutes @ [0] points/s, [23.469388]p/c complete, ETA [18.468470] minutes
# [Process-37] [37] of [98] points, running [5.664737] minutes @ [0] points/s, [37.755102]p/c complete, ETA [9.339161] minutes
# [Process-40] [16] of [106] points, running [5.676364] minutes @ [0] points/s, [15.094340]p/c complete, ETA [31.929548] minutes
# [Process-33] [19] of [98] points, running [5.714864] minutes @ [0] points/s, [19.387755]p/c complete, ETA [23.761801] minutes
# [Process-37] [38] of [98] points, running [5.715397] minutes @ [0] points/s, [38.775510]p/c complete, ETA [9.024312] minutes
# [Process-31] [23] of [98] points, running [5.721427] minutes @ [0] points/s, [23.469388]p/c complete, ETA [18.656827] minutes
# [Process-40] [17] of [106] points, running [5.736543] minutes @ [0] points/s, [16.037736]p/c complete, ETA [30.032489] minutes
# [Process-32] [13] of [98] points, running [5.746398] minutes @ [0] points/s, [13.265306]p/c complete, ETA [37.572605] minutes
# [Process-39] [24] of [98] points, running [5.781990] minutes @ [0] points/s, [24.489796]p/c complete, ETA [17.827802] minutes
# [Process-32] [14] of [98] points, running [5.792757] minutes @ [0] points/s, [14.285714]p/c complete, ETA [34.756542] minutes
# [Process-32] [15] of [98] points, running [5.836133] minutes @ [0] points/s, [15.306122]p/c complete, ETA [32.293270] minutes
# [Process-33] [20] of [98] points, running [5.852157] minutes @ [0] points/s, [20.408163]p/c complete, ETA [22.823410] minutes
# [Process-33] [21] of [98] points, running [5.928817] minutes @ [0] points/s, [21.428571]p/c complete, ETA [21.738995] minutes
# [Process-33] [22] of [98] points, running [5.967867] minutes @ [0] points/s, [22.448980]p/c complete, ETA [20.616266] minutes
# [Process-39] [25] of [98] points, running [5.998347] minutes @ [0] points/s, [25.510204]p/c complete, ETA [17.515173] minutes
# [Process-38] [25] of [98] points, running [6.007839] minutes @ [0] points/s, [25.510204]p/c complete, ETA [17.542889] minutes
# [Process-35] [31] of [98] points, running [6.026669] minutes @ [0] points/s, [31.632653]p/c complete, ETA [13.025381] minutes
# [Process-36] [24] of [98] points, running [6.047071] minutes @ [0] points/s, [24.489796]p/c complete, ETA [18.645135] minutes
# [Process-33] [23] of [98] points, running [6.056560] minutes @ [0] points/s, [23.469388]p/c complete, ETA [19.749652] minutes
# [Process-39] [26] of [98] points, running [6.081228] minutes @ [0] points/s, [26.530612]p/c complete, ETA [16.840324] minutes
# [Process-35] [32] of [98] points, running [6.081709] minutes @ [0] points/s, [32.653061]p/c complete, ETA [12.543524] minutes
# [Process-36] [25] of [98] points, running [6.089305] minutes @ [0] points/s, [25.510204]p/c complete, ETA [17.780771] minutes
# [Process-39] [27] of [98] points, running [6.114107] minutes @ [0] points/s, [27.551020]p/c complete, ETA [16.077836] minutes
# [Process-36] [26] of [98] points, running [6.446887] minutes @ [0] points/s, [26.530612]p/c complete, ETA [17.852917] minutes
# [Process-39] [28] of [98] points, running [6.455523] minutes @ [0] points/s, [28.571429]p/c complete, ETA [16.138808] minutes
# [Process-38] [26] of [98] points, running [6.468896] minutes @ [0] points/s, [26.530612]p/c complete, ETA [17.913865] minutes
# [Process-35] [33] of [98] points, running [6.503569] minutes @ [0] points/s, [33.673469]p/c complete, ETA [12.810061] minutes
# [Process-35] [34] of [98] points, running [6.546622] minutes @ [0] points/s, [34.693878]p/c complete, ETA [12.323054] minutes
# [Process-40] [18] of [106] points, running [6.600634] minutes @ [0] points/s, [16.981132]p/c complete, ETA [32.269764] minutes
# [Process-38] [27] of [98] points, running [6.619574] minutes @ [0] points/s, [27.551020]p/c complete, ETA [17.407027] minutes
# [Process-40] [19] of [106] points, running [6.637090] minutes @ [0] points/s, [17.924528]p/c complete, ETA [30.390886] minutes
# [Process-40] [20] of [106] points, running [6.666440] minutes @ [0] points/s, [18.867925]p/c complete, ETA [28.665692] minutes
# [Process-34] [28] of [98] points, running [6.695292] minutes @ [0] points/s, [28.571429]p/c complete, ETA [16.738231] minutes
# [Process-40] [21] of [106] points, running [6.695388] minutes @ [0] points/s, [19.811321]p/c complete, ETA [27.100381] minutes
# [Process-37] [39] of [98] points, running [6.702110] minutes @ [0] points/s, [39.795918]p/c complete, ETA [10.139090] minutes
# [Process-37] [40] of [98] points, running [6.740843] minutes @ [0] points/s, [40.816327]p/c complete, ETA [9.774223] minutes
# [Process-31] [24] of [98] points, running [6.792676] minutes @ [0] points/s, [24.489796]p/c complete, ETA [20.944085] minutes
# [Process-37] [41] of [98] points, running [6.880613] minutes @ [0] points/s, [41.836735]p/c complete, ETA [9.565730] minutes
# [Process-31] [25] of [98] points, running [6.886101] minutes @ [0] points/s, [25.510204]p/c complete, ETA [20.107416] minutes
# [Process-33] [24] of [98] points, running [6.908246] minutes @ [0] points/s, [24.489796]p/c complete, ETA [21.300425] minutes
# [Process-38] [28] of [98] points, running [6.916265] minutes @ [0] points/s, [28.571429]p/c complete, ETA [17.290663] minutes
# [Process-37] [42] of [98] points, running [6.957347] minutes @ [0] points/s, [42.857143]p/c complete, ETA [9.276462] minutes
# [Process-33] [25] of [98] points, running [6.976688] minutes @ [0] points/s, [25.510204]p/c complete, ETA [20.371930] minutes
# [Process-37] [43] of [98] points, running [6.999405] minutes @ [0] points/s, [43.877551]p/c complete, ETA [8.952727] minutes
# [Process-32] [16] of [98] points, running [7.065291] minutes @ [0] points/s, [16.326531]p/c complete, ETA [36.209614] minutes
# [Process-37] [44] of [98] points, running [7.068118] minutes @ [0] points/s, [44.897959]p/c complete, ETA [8.674509] minutes
# [Process-38] [29] of [98] points, running [7.070389] minutes @ [0] points/s, [29.591837]p/c complete, ETA [16.822649] minutes
# [Process-32] [17] of [98] points, running [7.117583] minutes @ [0] points/s, [17.346939]p/c complete, ETA [33.913188] minutes
# [Process-37] [45] of [98] points, running [7.121725] minutes @ [0] points/s, [45.918367]p/c complete, ETA [8.387810] minutes
# [Process-34] [29] of [98] points, running [7.127925] minutes @ [0] points/s, [29.591837]p/c complete, ETA [16.959546] minutes
# [Process-32] [18] of [98] points, running [7.168362] minutes @ [0] points/s, [18.367347]p/c complete, ETA [31.859385] minutes
# [Process-37] [46] of [98] points, running [7.169819] minutes @ [0] points/s, [46.938776]p/c complete, ETA [8.105012] minutes
# [Process-37] [47] of [98] points, running [7.251035] minutes @ [0] points/s, [47.959184]p/c complete, ETA [7.868144] minutes
# [Process-32] [19] of [98] points, running [7.257944] minutes @ [0] points/s, [19.387755]p/c complete, ETA [30.177766] minutes
# [Process-38] [30] of [98] points, running [7.277539] minutes @ [0] points/s, [30.612245]p/c complete, ETA [16.495756] minutes
# [Process-32] [20] of [98] points, running [7.313419] minutes @ [0] points/s, [20.408163]p/c complete, ETA [28.522336] minutes
# [Process-35] [35] of [98] points, running [7.362051] minutes @ [0] points/s, [35.714286]p/c complete, ETA [13.251692] minutes
# [Process-35] [36] of [98] points, running [7.398972] minutes @ [0] points/s, [36.734694]p/c complete, ETA [12.742675] minutes
# [Process-35] [37] of [98] points, running [7.436713] minutes @ [0] points/s, [37.755102]p/c complete, ETA [12.260527] minutes
# [Process-31] [26] of [98] points, running [7.470748] minutes @ [0] points/s, [26.530612]p/c complete, ETA [20.688226] minutes
# [Process-35] [38] of [98] points, running [7.492463] minutes @ [0] points/s, [38.775510]p/c complete, ETA [11.830205] minutes
# [Process-35] [39] of [98] points, running [7.537138] minutes @ [0] points/s, [39.795918]p/c complete, ETA [11.402337] minutes
# [Process-31] [27] of [98] points, running [7.567969] minutes @ [0] points/s, [27.551020]p/c complete, ETA [19.900955] minutes
# [Process-35] [40] of [98] points, running [7.591090] minutes @ [0] points/s, [40.816327]p/c complete, ETA [11.007081] minutes
# [Process-40] [22] of [106] points, running [7.625552] minutes @ [0] points/s, [20.754717]p/c complete, ETA [29.115745] minutes
# [Process-35] [41] of [98] points, running [7.631291] minutes @ [0] points/s, [41.836735]p/c complete, ETA [10.609356] minutes
# [Process-40] [23] of [106] points, running [7.667397] minutes @ [0] points/s, [21.698113]p/c complete, ETA [27.669301] minutes
# [Process-36] [27] of [98] points, running [7.672350] minutes @ [0] points/s, [27.551020]p/c complete, ETA [20.175439] minutes
# [Process-35] [42] of [98] points, running [7.717839] minutes @ [0] points/s, [42.857143]p/c complete, ETA [10.290451] minutes
# [Process-40] [24] of [106] points, running [7.750493] minutes @ [0] points/s, [22.641509]p/c complete, ETA [26.480851] minutes
# [Process-36] [28] of [98] points, running [7.773388] minutes @ [0] points/s, [28.571429]p/c complete, ETA [19.433470] minutes
# [Process-36] [29] of [98] points, running [7.822931] minutes @ [0] points/s, [29.591837]p/c complete, ETA [18.613181] minutes
# [Process-33] [26] of [98] points, running [7.844573] minutes @ [0] points/s, [26.530612]p/c complete, ETA [21.723433] minutes
# [Process-37] [48] of [98] points, running [7.899521] minutes @ [0] points/s, [48.979592]p/c complete, ETA [8.228668] minutes
# [Process-39] [29] of [98] points, running [7.914843] minutes @ [0] points/s, [29.591837]p/c complete, ETA [18.831867] minutes
# [Process-34] [30] of [98] points, running [7.933434] minutes @ [0] points/s, [30.612245]p/c complete, ETA [17.982451] minutes
# [Process-37] [49] of [98] points, running [7.936831] minutes @ [0] points/s, [50.000000]p/c complete, ETA [7.936831] minutes
# [Process-34] [31] of [98] points, running [7.985483] minutes @ [0] points/s, [31.632653]p/c complete, ETA [17.258946] minutes
# [Process-37] [50] of [98] points, running [7.990979] minutes @ [0] points/s, [51.020408]p/c complete, ETA [7.671340] minutes
# [Process-37] [51] of [98] points, running [8.034351] minutes @ [0] points/s, [52.040816]p/c complete, ETA [7.404205] minutes
# [Process-40] [25] of [106] points, running [8.065877] minutes @ [0] points/s, [23.584906]p/c complete, ETA [26.133443] minutes
# [Process-39] [30] of [98] points, running [8.070912] minutes @ [0] points/s, [30.612245]p/c complete, ETA [18.294068] minutes
# [Process-37] [52] of [98] points, running [8.093143] minutes @ [0] points/s, [53.061224]p/c complete, ETA [7.159319] minutes
# [Process-40] [26] of [106] points, running [8.118896] minutes @ [0] points/s, [24.528302]p/c complete, ETA [24.981219] minutes
# [Process-39] [31] of [98] points, running [8.135163] minutes @ [0] points/s, [31.632653]p/c complete, ETA [17.582448] minutes
# [Process-35] [43] of [98] points, running [8.170165] minutes @ [0] points/s, [43.877551]p/c complete, ETA [10.450211] minutes
# [Process-40] [27] of [106] points, running [8.192338] minutes @ [0] points/s, [25.471698]p/c complete, ETA [23.970174] minutes
# [Process-36] [30] of [98] points, running [8.199223] minutes @ [0] points/s, [30.612245]p/c complete, ETA [18.584905] minutes
# [Process-39] [32] of [98] points, running [8.200130] minutes @ [0] points/s, [32.653061]p/c complete, ETA [16.912768] minutes
# [Process-33] [27] of [98] points, running [8.235261] minutes @ [0] points/s, [27.551020]p/c complete, ETA [21.655687] minutes
# [Process-37] [53] of [98] points, running [8.242873] minutes @ [0] points/s, [54.081633]p/c complete, ETA [6.998666] minutes
# [Process-40] [28] of [106] points, running [8.244663] minutes @ [0] points/s, [26.415094]p/c complete, ETA [22.967276] minutes
# [Process-32] [21] of [98] points, running [8.273657] minutes @ [0] points/s, [21.428571]p/c complete, ETA [30.336742] minutes
# [Process-34] [32] of [98] points, running [8.283188] minutes @ [0] points/s, [32.653061]p/c complete, ETA [17.084074] minutes
# [Process-35] [44] of [98] points, running [8.286165] minutes @ [0] points/s, [44.897959]p/c complete, ETA [10.169384] minutes
# [Process-39] [33] of [98] points, running [8.321902] minutes @ [0] points/s, [33.673469]p/c complete, ETA [16.391625] minutes
# [Process-40] [29] of [106] points, running [8.323773] minutes @ [0] points/s, [27.358491]p/c complete, ETA [22.101053] minutes
# [Process-35] [45] of [98] points, running [8.345351] minutes @ [0] points/s, [45.918367]p/c complete, ETA [9.828969] minutes
# [Process-34] [33] of [98] points, running [8.361443] minutes @ [0] points/s, [33.673469]p/c complete, ETA [16.469509] minutes
# [Process-36] [31] of [98] points, running [8.372111] minutes @ [0] points/s, [31.632653]p/c complete, ETA [18.094563] minutes
# [Process-32] [22] of [98] points, running [8.378718] minutes @ [0] points/s, [22.448980]p/c complete, ETA [28.944663] minutes
# [Process-40] [30] of [106] points, running [8.388212] minutes @ [0] points/s, [28.301887]p/c complete, ETA [21.250137] minutes
# [Process-39] [34] of [98] points, running [8.398619] minutes @ [0] points/s, [34.693878]p/c complete, ETA [15.809164] minutes
# [Process-39] [35] of [98] points, running [8.436183] minutes @ [0] points/s, [35.714286]p/c complete, ETA [15.185130] minutes
# [Process-34] [34] of [98] points, running [8.452776] minutes @ [0] points/s, [34.693878]p/c complete, ETA [15.911108] minutes
# [Process-32] [23] of [98] points, running [8.470692] minutes @ [0] points/s, [23.469388]p/c complete, ETA [27.621823] minutes
# [Process-39] [36] of [98] points, running [8.484436] minutes @ [0] points/s, [36.734694]p/c complete, ETA [14.612084] minutes
# [Process-34] [35] of [98] points, running [8.504091] minutes @ [0] points/s, [35.714286]p/c complete, ETA [15.307364] minutes
# [Process-32] [24] of [98] points, running [8.531741] minutes @ [0] points/s, [24.489796]p/c complete, ETA [26.306202] minutes
# [Process-39] [37] of [98] points, running [8.537361] minutes @ [0] points/s, [37.755102]p/c complete, ETA [14.075109] minutes
# [Process-31] [28] of [98] points, running [8.540065] minutes @ [0] points/s, [28.571429]p/c complete, ETA [21.350162] minutes
# [Process-32] [25] of [98] points, running [8.578846] minutes @ [0] points/s, [25.510204]p/c complete, ETA [25.050231] minutes
# [Process-31] [29] of [98] points, running [8.597097] minutes @ [0] points/s, [29.591837]p/c complete, ETA [20.455163] minutes
# [Process-39] [38] of [98] points, running [8.597466] minutes @ [0] points/s, [38.775510]p/c complete, ETA [13.574947] minutes
# [Process-39] [39] of [98] points, running [8.654543] minutes @ [0] points/s, [39.795918]p/c complete, ETA [13.092770] minutes
# [Process-38] [31] of [98] points, running [8.654947] minutes @ [0] points/s, [31.632653]p/c complete, ETA [18.705854] minutes
# [Process-31] [30] of [98] points, running [8.658191] minutes @ [0] points/s, [30.612245]p/c complete, ETA [19.625233] minutes
# [Process-35] [46] of [98] points, running [8.708822] minutes @ [0] points/s, [46.938776]p/c complete, ETA [9.844756] minutes
# [Process-35] [47] of [98] points, running [8.743823] minutes @ [0] points/s, [47.959184]p/c complete, ETA [9.487978] minutes
# [Process-39] [40] of [98] points, running [8.751448] minutes @ [0] points/s, [40.816327]p/c complete, ETA [12.689599] minutes
# [Process-35] [48] of [98] points, running [8.796323] minutes @ [0] points/s, [48.979592]p/c complete, ETA [9.162836] minutes
# [Process-32] [26] of [98] points, running [8.834922] minutes @ [0] points/s, [26.530612]p/c complete, ETA [24.465937] minutes
# [Process-35] [49] of [98] points, running [8.840643] minutes @ [0] points/s, [50.000000]p/c complete, ETA [8.840643] minutes
# [Process-33] [28] of [98] points, running [8.884853] minutes @ [0] points/s, [28.571429]p/c complete, ETA [22.212133] minutes
# [Process-35] [50] of [98] points, running [8.888252] minutes @ [0] points/s, [51.020408]p/c complete, ETA [8.532722] minutes
# [Process-32] [27] of [98] points, running [8.896860] minutes @ [0] points/s, [27.551020]p/c complete, ETA [23.395448] minutes
# [Process-31] [31] of [98] points, running [8.937682] minutes @ [0] points/s, [31.632653]p/c complete, ETA [19.316926] minutes
# [Process-33] [29] of [98] points, running [8.938159] minutes @ [0] points/s, [29.591837]p/c complete, ETA [21.266655] minutes
# [Process-35] [51] of [98] points, running [8.943856] minutes @ [0] points/s, [52.040816]p/c complete, ETA [8.242377] minutes
# [Process-31] [32] of [98] points, running [8.973833] minutes @ [0] points/s, [32.653061]p/c complete, ETA [18.508530] minutes
# [Process-32] [28] of [98] points, running [9.007618] minutes @ [0] points/s, [28.571429]p/c complete, ETA [22.519044] minutes
# [Process-31] [33] of [98] points, running [9.009850] minutes @ [0] points/s, [33.673469]p/c complete, ETA [17.746674] minutes
# [Process-32] [29] of [98] points, running [9.047348] minutes @ [0] points/s, [29.591837]p/c complete, ETA [21.526449] minutes
# [Process-31] [34] of [98] points, running [9.060282] minutes @ [0] points/s, [34.693878]p/c complete, ETA [17.054648] minutes
# [Process-38] [32] of [98] points, running [9.106577] minutes @ [0] points/s, [32.653061]p/c complete, ETA [18.782314] minutes
# [Process-38] [33] of [98] points, running [9.146830] minutes @ [0] points/s, [33.673469]p/c complete, ETA [18.016484] minutes
# [Process-38] [34] of [98] points, running [9.181309] minutes @ [0] points/s, [34.693878]p/c complete, ETA [17.282463] minutes
# [Process-35] [52] of [98] points, running [9.183266] minutes @ [0] points/s, [53.061224]p/c complete, ETA [8.123658] minutes
# [Process-38] [35] of [98] points, running [9.239941] minutes @ [0] points/s, [35.714286]p/c complete, ETA [16.631894] minutes
# [Process-35] [53] of [98] points, running [9.242797] minutes @ [0] points/s, [54.081633]p/c complete, ETA [7.847657] minutes
# [Process-33] [30] of [98] points, running [9.279664] minutes @ [0] points/s, [30.612245]p/c complete, ETA [21.033906] minutes
# [Process-38] [36] of [98] points, running [9.283876] minutes @ [0] points/s, [36.734694]p/c complete, ETA [15.988898] minutes
# [Process-32] [30] of [98] points, running [9.317079] minutes @ [0] points/s, [30.612245]p/c complete, ETA [21.118712] minutes
# [Process-40] [31] of [106] points, running [9.320008] minutes @ [0] points/s, [29.245283]p/c complete, ETA [22.548407] minutes
# [Process-33] [31] of [98] points, running [9.334734] minutes @ [0] points/s, [31.632653]p/c complete, ETA [20.175071] minutes
# [Process-38] [37] of [98] points, running [9.344196] minutes @ [0] points/s, [37.755102]p/c complete, ETA [15.405296] minutes
# [Process-34] [36] of [98] points, running [9.371112] minutes @ [0] points/s, [36.734694]p/c complete, ETA [16.139137] minutes
# [Process-40] [32] of [106] points, running [9.373460] minutes @ [0] points/s, [30.188679]p/c complete, ETA [21.676126] minutes
# [Process-33] [32] of [98] points, running [9.390188] minutes @ [0] points/s, [32.653061]p/c complete, ETA [19.367263] minutes
# [Process-38] [38] of [98] points, running [9.405692] minutes @ [0] points/s, [38.775510]p/c complete, ETA [14.851093] minutes
# [Process-40] [33] of [106] points, running [9.436417] minutes @ [0] points/s, [31.132075]p/c complete, ETA [20.874499] minutes
# [Process-38] [39] of [98] points, running [9.454838] minutes @ [0] points/s, [39.795918]p/c complete, ETA [14.303473] minutes
# ...
# [Process-34] [90] of [98] points, running [19.803277] minutes @ [0] points/s, [91.836735]p/c complete, ETA [1.760291] minutes
# [Process-31] [80] of [98] points, running [19.824274] minutes @ [0] points/s, [81.632653]p/c complete, ETA [4.460462] minutes
# [Process-35] [98] of [98] points, running [19.828744] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-40] [84] of [106] points, running [19.852220] minutes @ [0] points/s, [79.245283]p/c complete, ETA [5.199391] minutes
# [Process-34] [91] of [98] points, running [19.869796] minutes @ [0] points/s, [92.857143]p/c complete, ETA [1.528446] minutes
# [Process-34] [92] of [98] points, running [19.976067] minutes @ [0] points/s, [93.877551]p/c complete, ETA [1.302787] minutes
# [Process-40] [85] of [106] points, running [20.043866] minutes @ [0] points/s, [80.188679]p/c complete, ETA [4.952014] minutes
# [Process-37] [94] of [98] points, running [20.047840] minutes @ [0] points/s, [95.918367]p/c complete, ETA [0.853100] minutes
# [Process-37] [95] of [98] points, running [20.090713] minutes @ [0] points/s, [96.938776]p/c complete, ETA [0.634444] minutes
# [Process-35] DONE! Wrote [98] points to [data/uber-simulation/points-process-35.csv]
# [Process-40] [86] of [106] points, running [20.102762] minutes @ [0] points/s, [81.132075]p/c complete, ETA [4.675061] minutes
# [Process-37] [96] of [98] points, running [20.135391] minutes @ [0] points/s, [97.959184]p/c complete, ETA [0.419487] minutes
# [Process-33] [75] of [98] points, running [20.154583] minutes @ [0] points/s, [76.530612]p/c complete, ETA [6.180739] minutes
# [Process-37] [97] of [98] points, running [20.180895] minutes @ [0] points/s, [98.979592]p/c complete, ETA [0.208050] minutes
# [Process-33] [76] of [98] points, running [20.197148] minutes @ [0] points/s, [77.551020]p/c complete, ETA [5.846543] minutes
# [Process-40] [87] of [106] points, running [20.198389] minutes @ [0] points/s, [82.075472]p/c complete, ETA [4.411142] minutes
# [Process-33] [77] of [98] points, running [20.239220] minutes @ [0] points/s, [78.571429]p/c complete, ETA [5.519787] minutes
# [Process-40] [88] of [106] points, running [20.259443] minutes @ [0] points/s, [83.018868]p/c complete, ETA [4.143977] minutes
# [Process-34] [93] of [98] points, running [20.279060] minutes @ [0] points/s, [94.897959]p/c complete, ETA [1.090272] minutes
# [Process-33] [78] of [98] points, running [20.281794] minutes @ [0] points/s, [79.591837]p/c complete, ETA [5.200460] minutes
# [Process-32] [81] of [98] points, running [20.287285] minutes @ [0] points/s, [82.653061]p/c complete, ETA [4.257825] minutes
# [Process-32] [82] of [98] points, running [20.321973] minutes @ [0] points/s, [83.673469]p/c complete, ETA [3.965263] minutes
# [Process-40] [89] of [106] points, running [20.326666] minutes @ [0] points/s, [83.962264]p/c complete, ETA [3.882622] minutes
# [Process-34] [94] of [98] points, running [20.342664] minutes @ [0] points/s, [95.918367]p/c complete, ETA [0.865645] minutes
# [Process-39] [80] of [98] points, running [20.344054] minutes @ [0] points/s, [81.632653]p/c complete, ETA [4.577412] minutes
# [Process-39] [81] of [98] points, running [20.379580] minutes @ [0] points/s, [82.653061]p/c complete, ETA [4.277196] minutes
# [Process-34] [95] of [98] points, running [20.399591] minutes @ [0] points/s, [96.938776]p/c complete, ETA [0.644198] minutes
# [Process-32] [83] of [98] points, running [20.434163] minutes @ [0] points/s, [84.693878]p/c complete, ETA [3.692921] minutes
# [Process-34] [96] of [98] points, running [20.434179] minutes @ [0] points/s, [97.959184]p/c complete, ETA [0.425712] minutes
# [Process-39] [82] of [98] points, running [20.436165] minutes @ [0] points/s, [83.673469]p/c complete, ETA [3.987544] minutes
# [Process-40] [90] of [106] points, running [20.476095] minutes @ [0] points/s, [84.905660]p/c complete, ETA [3.640195] minutes
# [Process-32] [84] of [98] points, running [20.480865] minutes @ [0] points/s, [85.714286]p/c complete, ETA [3.413477] minutes
# [Process-39] [83] of [98] points, running [20.500657] minutes @ [0] points/s, [84.693878]p/c complete, ETA [3.704938] minutes
# [Process-40] [91] of [106] points, running [20.513565] minutes @ [0] points/s, [85.849057]p/c complete, ETA [3.381357] minutes
# [Process-40] [92] of [106] points, running [20.562878] minutes @ [0] points/s, [86.792453]p/c complete, ETA [3.129134] minutes
# [Process-40] [93] of [106] points, running [20.600907] minutes @ [0] points/s, [87.735849]p/c complete, ETA [2.879697] minutes
# [Process-31] [81] of [98] points, running [20.644854] minutes @ [0] points/s, [82.653061]p/c complete, ETA [4.332871] minutes
# [Process-40] [94] of [106] points, running [20.651581] minutes @ [0] points/s, [88.679245]p/c complete, ETA [2.636372] minutes
# [Process-31] [82] of [98] points, running [20.686331] minutes @ [0] points/s, [83.673469]p/c complete, ETA [4.036357] minutes
# [Process-39] [84] of [98] points, running [20.686979] minutes @ [0] points/s, [85.714286]p/c complete, ETA [3.447830] minutes
# [Process-31] [83] of [98] points, running [20.740979] minutes @ [0] points/s, [84.693878]p/c complete, ETA [3.748370] minutes
# [Process-39] [85] of [98] points, running [20.765592] minutes @ [0] points/s, [86.734694]p/c complete, ETA [3.175914] minutes
# [Process-31] [84] of [98] points, running [20.780674] minutes @ [0] points/s, [85.714286]p/c complete, ETA [3.463446] minutes
# [Process-40] [95] of [106] points, running [20.792258] minutes @ [0] points/s, [89.622642]p/c complete, ETA [2.407525] minutes
# [Process-31] [85] of [98] points, running [20.826695] minutes @ [0] points/s, [86.734694]p/c complete, ETA [3.185259] minutes
# [Process-40] [96] of [106] points, running [20.846132] minutes @ [0] points/s, [90.566038]p/c complete, ETA [2.171472] minutes
# [Process-39] [86] of [98] points, running [20.877792] minutes @ [0] points/s, [87.755102]p/c complete, ETA [2.913180] minutes
# [Process-37] [98] of [98] points, running [20.892843] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-40] [97] of [106] points, running [20.898164] minutes @ [0] points/s, [91.509434]p/c complete, ETA [1.939005] minutes
# [Process-32] [85] of [98] points, running [20.907084] minutes @ [0] points/s, [86.734694]p/c complete, ETA [3.197554] minutes
# [Process-40] [98] of [106] points, running [20.940950] minutes @ [0] points/s, [92.452830]p/c complete, ETA [1.709465] minutes
# [Process-32] [86] of [98] points, running [20.942093] minutes @ [0] points/s, [87.755102]p/c complete, ETA [2.922153] minutes
# [Process-40] [99] of [106] points, running [20.975549] minutes @ [0] points/s, [93.396226]p/c complete, ETA [1.483120] minutes
# [Process-32] [87] of [98] points, running [20.983157] minutes @ [0] points/s, [88.775510]p/c complete, ETA [2.653043] minutes
# [Process-32] [88] of [98] points, running [21.015711] minutes @ [0] points/s, [89.795918]p/c complete, ETA [2.388149] minutes
# [Process-40] [100] of [106] points, running [21.037939] minutes @ [0] points/s, [94.339623]p/c complete, ETA [1.262276] minutes
# [Process-32] [89] of [98] points, running [21.056639] minutes @ [0] points/s, [90.816327]p/c complete, ETA [2.129323] minutes
# [Process-32] [90] of [98] points, running [21.093852] minutes @ [0] points/s, [91.836735]p/c complete, ETA [1.875009] minutes
# [Process-32] [91] of [98] points, running [21.131724] minutes @ [0] points/s, [92.857143]p/c complete, ETA [1.625517] minutes
# [Process-37] DONE! Wrote [98] points to [data/uber-simulation/points-process-37.csv]
# [Process-39] [87] of [98] points, running [21.156721] minutes @ [0] points/s, [88.775510]p/c complete, ETA [2.674988] minutes
# [Process-32] [92] of [98] points, running [21.163581] minutes @ [0] points/s, [93.877551]p/c complete, ETA [1.380234] minutes
# [Process-32] [93] of [98] points, running [21.190136] minutes @ [0] points/s, [94.897959]p/c complete, ETA [1.139255] minutes
# [Process-32] [94] of [98] points, running [21.216114] minutes @ [0] points/s, [95.918367]p/c complete, ETA [0.902813] minutes
# [Process-40] [101] of [106] points, running [21.271495] minutes @ [0] points/s, [95.283019]p/c complete, ETA [1.053044] minutes
# [Process-40] [102] of [106] points, running [21.299193] minutes @ [0] points/s, [96.226415]p/c complete, ETA [0.835262] minutes
# [Process-34] [97] of [98] points, running [21.324418] minutes @ [0] points/s, [98.979592]p/c complete, ETA [0.219839] minutes
# [Process-32] [95] of [98] points, running [21.325412] minutes @ [0] points/s, [96.938776]p/c complete, ETA [0.673434] minutes
# [Process-33] [79] of [98] points, running [21.430191] minutes @ [0] points/s, [80.612245]p/c complete, ETA [5.154097] minutes
# [Process-31] [86] of [98] points, running [21.440980] minutes @ [0] points/s, [87.755102]p/c complete, ETA [2.991765] minutes
# [Process-31] [87] of [98] points, running [21.469780] minutes @ [0] points/s, [88.775510]p/c complete, ETA [2.714570] minutes
# [Process-33] [80] of [98] points, running [21.518848] minutes @ [0] points/s, [81.632653]p/c complete, ETA [4.841741] minutes
# [Process-31] [88] of [98] points, running [21.549114] minutes @ [0] points/s, [89.795918]p/c complete, ETA [2.448763] minutes
# [Process-31] [89] of [98] points, running [21.576645] minutes @ [0] points/s, [90.816327]p/c complete, ETA [2.181908] minutes
# [Process-31] [90] of [98] points, running [21.680949] minutes @ [0] points/s, [91.836735]p/c complete, ETA [1.927195] minutes
# [Process-32] [96] of [98] points, running [21.696680] minutes @ [0] points/s, [97.959184]p/c complete, ETA [0.452014] minutes
# [Process-33] [81] of [98] points, running [21.743922] minutes @ [0] points/s, [82.653061]p/c complete, ETA [4.563539] minutes
# [Process-31] [91] of [98] points, running [21.746262] minutes @ [0] points/s, [92.857143]p/c complete, ETA [1.672789] minutes
# [Process-32] [97] of [98] points, running [21.757391] minutes @ [0] points/s, [98.979592]p/c complete, ETA [0.224303] minutes
# [Process-31] [92] of [98] points, running [21.788222] minutes @ [0] points/s, [93.877551]p/c complete, ETA [1.420971] minutes
# [Process-32] [98] of [98] points, running [21.929207] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-31] [93] of [98] points, running [21.947790] minutes @ [0] points/s, [94.897959]p/c complete, ETA [1.179989] minutes
# [Process-40] [103] of [106] points, running [21.948132] minutes @ [0] points/s, [97.169811]p/c complete, ETA [0.639266] minutes
# [Process-31] [94] of [98] points, running [21.979873] minutes @ [0] points/s, [95.918367]p/c complete, ETA [0.935314] minutes
# [Process-40] [104] of [106] points, running [21.990374] minutes @ [0] points/s, [98.113208]p/c complete, ETA [0.422892] minutes
# [Process-39] [88] of [98] points, running [22.001988] minutes @ [0] points/s, [89.795918]p/c complete, ETA [2.500226] minutes
# [Process-31] [95] of [98] points, running [22.023284] minutes @ [0] points/s, [96.938776]p/c complete, ETA [0.695472] minutes
# [Process-40] [105] of [106] points, running [22.039206] minutes @ [0] points/s, [99.056604]p/c complete, ETA [0.209897] minutes
# [Process-40] [106] of [106] points, running [22.067542] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-34] [98] of [98] points, running [22.078887] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-32] DONE! Wrote [98] points to [data/uber-simulation/points-process-32.csv]
# [Process-39] [89] of [98] points, running [22.213553] minutes @ [0] points/s, [90.816327]p/c complete, ETA [2.246314] minutes
# [Process-39] [90] of [98] points, running [22.255375] minutes @ [0] points/s, [91.836735]p/c complete, ETA [1.978256] minutes
# [Process-39] [91] of [98] points, running [22.282712] minutes @ [0] points/s, [92.857143]p/c complete, ETA [1.714055] minutes
# [Process-40] DONE! Wrote [106] points to [data/uber-simulation/points-process-40.csv]
# [Process-34] DONE! Wrote [98] points to [data/uber-simulation/points-process-34.csv]
# [Process-39] [92] of [98] points, running [22.335890] minutes @ [0] points/s, [93.877551]p/c complete, ETA [1.456688] minutes
# [Process-39] [93] of [98] points, running [22.398210] minutes @ [0] points/s, [94.897959]p/c complete, ETA [1.204205] minutes
# [Process-39] [94] of [98] points, running [22.460431] minutes @ [0] points/s, [95.918367]p/c complete, ETA [0.955763] minutes
# [Process-39] [95] of [98] points, running [22.547613] minutes @ [0] points/s, [96.938776]p/c complete, ETA [0.712030] minutes
# [Process-31] [96] of [98] points, running [22.565338] minutes @ [0] points/s, [97.959184]p/c complete, ETA [0.470111] minutes
# [Process-39] [96] of [98] points, running [22.588259] minutes @ [0] points/s, [97.959184]p/c complete, ETA [0.470589] minutes
# [Process-33] [82] of [98] points, running [22.628418] minutes @ [0] points/s, [83.673469]p/c complete, ETA [4.415301] minutes
# [Process-33] [83] of [98] points, running [22.667251] minutes @ [0] points/s, [84.693878]p/c complete, ETA [4.096491] minutes
# [Process-33] [84] of [98] points, running [22.699279] minutes @ [0] points/s, [85.714286]p/c complete, ETA [3.783213] minutes
# [Process-33] [85] of [98] points, running [22.735189] minutes @ [0] points/s, [86.734694]p/c complete, ETA [3.477147] minutes
# [Process-33] [86] of [98] points, running [22.760615] minutes @ [0] points/s, [87.755102]p/c complete, ETA [3.175900] minutes
# [Process-33] [87] of [98] points, running [22.788926] minutes @ [0] points/s, [88.775510]p/c complete, ETA [2.881359] minutes
# [Process-33] [88] of [98] points, running [22.819805] minutes @ [0] points/s, [89.795918]p/c complete, ETA [2.593160] minutes
# [Process-33] [89] of [98] points, running [23.003272] minutes @ [0] points/s, [90.816327]p/c complete, ETA [2.326174] minutes
# [Process-33] [90] of [98] points, running [23.030051] minutes @ [0] points/s, [91.836735]p/c complete, ETA [2.047116] minutes
# [Process-39] [97] of [98] points, running [23.282974] minutes @ [0] points/s, [98.979592]p/c complete, ETA [0.240031] minutes
# [Process-31] [97] of [98] points, running [23.286091] minutes @ [0] points/s, [98.979592]p/c complete, ETA [0.240063] minutes
# [Process-31] [98] of [98] points, running [23.341281] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-39] [98] of [98] points, running [23.368492] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-31] DONE! Wrote [98] points to [data/uber-simulation/points-process-31.csv]
# Process on this core: Done!
# Process on this core: Done!
# [Process-39] DONE! Wrote [98] points to [data/uber-simulation/points-process-39.csv]
# [Process-33] [91] of [98] points, running [23.773495] minutes @ [0] points/s, [92.857143]p/c complete, ETA [1.828730] minutes
# [Process-33] [92] of [98] points, running [23.796578] minutes @ [0] points/s, [93.877551]p/c complete, ETA [1.551951] minutes
# [Process-33] [93] of [98] points, running [23.836996] minutes @ [0] points/s, [94.897959]p/c complete, ETA [1.281559] minutes
# [Process-33] [94] of [98] points, running [23.956580] minutes @ [0] points/s, [95.918367]p/c complete, ETA [1.019429] minutes
# [Process-33] [95] of [98] points, running [23.992734] minutes @ [0] points/s, [96.938776]p/c complete, ETA [0.757665] minutes
# [Process-33] [96] of [98] points, running [24.548308] minutes @ [0] points/s, [97.959184]p/c complete, ETA [0.511423] minutes
# [Process-33] [97] of [98] points, running [24.637973] minutes @ [0] points/s, [98.979592]p/c complete, ETA [0.254000] minutes
# [Process-33] [98] of [98] points, running [24.681434] minutes @ [0] points/s, [100.000000]p/c complete, ETA [0.000000] minutes
# [Process-33] DONE! Wrote [98] points to [data/uber-simulation/points-process-33.csv]
# Process on this core: Done!
# Process on this core: Done!
# Process on this core: Done!
# Process on this core: Done!
# Process on this core: Done!
# Process on this core: Done!
# Process on this core: Done!
# Process on this core: Done!
# 2018.05.09 14:07
# Time to process all chunks: [24.96221850713094] minutes
