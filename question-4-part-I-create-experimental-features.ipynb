# %% [markdown]
# # Tip Prediction, Part II: Experimental Features

# %% [markdown]
# Author's Workday ID: C175799, Initials: RPR

# %% [markdown]
# ## Choose GPU

# %%
# From: https://github.com/keras-team/keras/issues/6031
import os
gpu_id = input( "Select GPU [0 or 1]: " )

if gpu_id in [ "0", "1" ]:
    os.environ[ "CUDA_VISIBLE_DEVICES" ] = gpu_id
else:
    print( "Invalid GPU id.  Defaulting to '0,1'" )
# Out:
# Select GPU [0 or 1]: 1

# %% [markdown]
# ## Imports and Util Functions

# %%
import pandas as pd
import numpy as np
import time
import datetime
import math
import random

def get_time( output=True ):
    
    temp = time.time()
    if output:
        now = datetime.datetime.now()
        print( now.strftime( "%Y.%m.%d %H:%M" ) )
        
    return temp

def print_time( start_time, end_time, interval="seconds" ):
    
    if interval == "hours":
        print ( "Time to process: [%s] hours" % ( str( ( end_time - start_time ) / 60 / 60 ) ) )
    elif interval == "minutes":
        print ( "Time to process: [%s] minutes" % ( str( ( end_time - start_time ) / 60 ) ) )
    else:
        print ( "Time to process: [%s] seconds" % ( str( end_time - start_time ) ) )

print_time( 0, 3600, interval="hours" )
print_time( 0, 3600, interval="minutes" )

verbose = False
# Out:
# Time to process: [1.0] hours
# Time to process: [60.0] minutes

# %% [markdown]
# ## Load Data

# %%
page_start = get_time()
trips = pd.read_csv( "data/green-tripdata-2015-09-cleaned.csv", compression="gzip" )
trips.columns = map( str.lower, trips.columns )
if verbose: print( list( trips.columns ) )
print_time( page_start, get_time() )
# Out:
# 2018.06.01 17:10
# 2018.06.01 17:10
# Time to process: [7.059286594390869] seconds

# %% [markdown]
# ## Add Payment Type Mean Encoding

# %%
rows = trips.shape[ 0 ]
# cc = 1
# cash = 2
trips_by_payment_type_grp = trips.groupby( "payment_type" ).payment_type.count()
print( trips_by_payment_type_grp / rows )
# Out:
# payment_type
# 1    0.469046
# 2    0.526515
# 3    0.002210
# 4    0.002186
# 5    0.000044
# Name: payment_type, dtype: float64

# %%
# Calculate a mapping: {payment_type: target_mean}
payment_type_target_mean = trips.groupby( 'payment_type' ).tip_recorded.mean()
print( payment_type_target_mean )

# In our non-regularized case we just *map* the computed means to the `payment_type`'s
trips[ 'payment_type_target_enc' ] = trips[ 'payment_type' ].map( payment_type_target_mean )
#trips.head()
# Out:
# payment_type
# 1    0.860920
# 2    0.000001
# 3    0.000000
# 4    0.000314
# 5    0.000000
# Name: tip_recorded, dtype: float64

# %% [markdown]
# ## Add Tip Percent Mean Encoding

# %%
trips_by_tip_percent_grp = trips.groupby( "tip_percent_bin" ).tip_percent_bin.count()
trips_by_tip_percent_grp[ "percent" ] = trips_by_tip_percent_grp / rows * 100
#trips_by_tip_percent_grp

#print( trips_by_tip_percent_grp / rows * 100 )
# 0.0      59.726507
# 1.0       0.068346
# 2.0       0.053234
# 3.0       0.068071
# 4.0       0.135112
# 5.0       0.212113
# 6.0       0.286640
# 7.0       0.351552
# 8.0       0.450258
# 9.0       0.481649

# %%
# add one-hot for tip_percent_bin
tip_bins = trips.tip_percent_bin.unique()
tip_bins.sort()
#print( tip_bins )

for tip in tip_bins:

    trips[ "tip_percent_bin_" + str( int ( tip ) ) ] = ( trips.tip_percent_bin == tip ) * 1
    
trips[ 0:5 ]
# Out:
#    vendorid  store_and_fwd_flag  ratecodeid  pickup_longitude  \
# 0         2               False           5        -73.979485
# 1         2               False           5        -74.010796
# 2         2               False           1        -73.921410
# 3         2               False           1        -73.921387
# 4         2               False           1        -73.955482
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0        40.684956         -73.979431         40.685020                1
# 1        40.912216         -74.010780         40.912212                1
# 2        40.766708         -73.914413         40.764687                1
# 3        40.766678         -73.931427         40.771584                1
# 4        40.714046         -73.944412         40.714729                1
#
#    trip_distance  fare_amount         ...           tip_percent_bin_120  \
# 0           0.00          7.8         ...                             0
# 1           0.00         45.0         ...                             0
# 2           0.59          4.0         ...                             0
# 3           0.74          5.0         ...                             0
# 4           0.61          5.0         ...                             0
#
#    tip_percent_bin_121  tip_percent_bin_122  tip_percent_bin_123  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    tip_percent_bin_124  tip_percent_bin_125  tip_percent_bin_126  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    tip_percent_bin_127  tip_percent_bin_128  tip_percent_bin_129
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
# [5 rows x 175 columns]

# %%
start_time = get_time()

# Calculate a mapping: {payment_type: target_mean}
for i in range( len( tip_bins ) ):
    
    bin_name = "tip_percent_bin_" + str( int( i ) )
    tip_bin_n_payment_type_mean = trips.groupby( 'payment_type' )[ bin_name ].mean() 
    tip_bin_n_ratecode_mean = trips.groupby( 'ratecodeid' )[ bin_name ].mean() 
    print( tip_bin_n_payment_type_mean )
    print( tip_bin_n_ratecode_mean )
    

    # create cols w/ default value: 0.0
    payment_type_col_name = "payment_type_tip_bin_" + str( i ) + "_enc"
    trips[ payment_type_col_name ] = 0.0

    ratecode_col_name = "ratecode_tip_bin_" + str( i ) + "_enc"
    trips[ ratecode_col_name ] = 0.0
    
    # In our non-regularized case we just *map* the computed means to the payment_type
    # See notebook for: https://www.coursera.org/learn/competitive-data-science/lecture/b5Gxv/concept-of-mean-encoding
    trips[ payment_type_col_name ] = trips[ 'payment_type' ].map( tip_bin_n_payment_type_mean )
    trips[ ratecode_col_name ] = trips[ 'ratecodeid' ].map( tip_bin_n_ratecode_mean )
    
    print() 
    
print_time( start_time, get_time(), interval="minutes" )
    
trips.head()
# Out:
# 2018.06.01 17:10
# payment_type
# 1    0.141376
# 2    0.999999
# 3    1.000000
# 4    0.999686
# 5    1.000000
# Name: tip_percent_bin_0, dtype: float64
# ratecodeid
# 1    0.592178
# 2    0.693263
# 3    0.692737
# 4    0.599628
# 5    0.860152
# 6    1.000000
# Name: tip_percent_bin_0, dtype: float64
#
# payment_type
# 1    0.001457
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_1, dtype: float64
# ratecodeid
# 1    0.000667
# 2    0.000000
# 3    0.002793
# 4    0.000000
# 5    0.001647
# 6    0.000000
# Name: tip_percent_bin_1, dtype: float64
#
# payment_type
# 1    0.001135
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_2, dtype: float64
# ratecodeid
# 1    0.000528
# 2    0.000310
# 3    0.001397
# 4    0.001862
# 5    0.000728
# 6    0.000000
# Name: tip_percent_bin_2, dtype: float64
#
# payment_type
# 1    0.001451
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_3, dtype: float64
# ratecodeid
# 1    0.000675
# 2    0.000310
# 3    0.000000
# 4    0.005587
# 5    0.000958
# 6    0.000000
# Name: tip_percent_bin_3, dtype: float64
#
# payment_type
# 1    0.002881
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_4, dtype: float64
# ratecodeid
# 1    0.001353
# 2    0.002794
# 3    0.001397
# 4    0.007449
# 5    0.000919
# 6    0.000000
# Name: tip_percent_bin_4, dtype: float64
#
# payment_type
# 1    0.004522
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_5, dtype: float64
# ratecodeid
# 1    0.002127
# 2    0.000931
# 3    0.002793
# 4    0.007449
# 5    0.001839
# 6    0.000000
# Name: tip_percent_bin_5, dtype: float64
#
# payment_type
# 1    0.006111
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_6, dtype: float64
# ratecodeid
# 1    0.002882
# 2    0.003415
# 3    0.004190
# 4    0.005587
# 5    0.001877
# 6    0.000000
# Name: tip_percent_bin_6, dtype: float64
#
# payment_type
# 1    0.007495
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_7, dtype: float64
# ratecodeid
# 1    0.003537
# 2    0.000931
# 3    0.001397
# 4    0.018622
# 5    0.002413
# 6    0.000000
# Name: tip_percent_bin_7, dtype: float64
#
# payment_type
# 1    0.009599
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_8, dtype: float64
# ratecodeid
# 1    0.004517
# 2    0.003415
# 3    0.004190
# 4    0.007449
# 5    0.003792
# 6    0.000000
# Name: tip_percent_bin_8, dtype: float64
#
# payment_type
# 1    0.010269
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_9, dtype: float64
# ratecodeid
# 1    0.004882
# 2    0.000000
# 3    0.002793
# 4    0.011173
# 5    0.001762
# 6    0.000000
# Name: tip_percent_bin_9, dtype: float64
#
# payment_type
# 1    0.013779
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_10, dtype: float64
# ratecodeid
# 1    0.006456
# 2    0.020491
# 3    0.009777
# 4    0.003724
# 5    0.005056
# 6    0.000000
# Name: tip_percent_bin_10, dtype: float64
#
# payment_type
# 1    0.017453
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_11, dtype: float64
# ratecodeid
# 1    0.008292
# 2    0.002173
# 3    0.006983
# 4    0.005587
# 5    0.003256
# 6    0.000000
# Name: tip_percent_bin_11, dtype: float64
#
# payment_type
# 1    0.018291
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_12, dtype: float64
# ratecodeid
# 1    0.008662
# 2    0.009935
# 3    0.008380
# 4    0.007449
# 5    0.003945
# 6    0.000000
# Name: tip_percent_bin_12, dtype: float64
#
# payment_type
# 1    0.01313
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_13, dtype: float64
# ratecodeid
# 1    0.006231
# 2    0.007762
# 3    0.004190
# 4    0.001862
# 5    0.002145
# 6    0.000000
# Name: tip_percent_bin_13, dtype: float64
#
# payment_type
# 1    0.015523
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_14, dtype: float64
# ratecodeid
# 1    0.007361
# 2    0.001242
# 3    0.006983
# 4    0.013035
# 5    0.003562
# 6    0.000000
# Name: tip_percent_bin_14, dtype: float64
#
# payment_type
# 1    0.016081
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_15, dtype: float64
# ratecodeid
# 1    0.007636
# 2    0.011177
# 3    0.008380
# 4    0.009311
# 5    0.001953
# 6    0.000000
# Name: tip_percent_bin_15, dtype: float64
#
# payment_type
# 1    0.011117
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_16, dtype: float64
# ratecodeid
# 1    0.005302
# 2    0.000621
# 3    0.004190
# 4    0.011173
# 5    0.000919
# 6    0.000000
# Name: tip_percent_bin_16, dtype: float64
#
# payment_type
# 1    0.017443
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_17, dtype: float64
# ratecodeid
# 1    0.008295
# 2    0.005278
# 3    0.004190
# 4    0.005587
# 5    0.002528
# 6    0.000000
# Name: tip_percent_bin_17, dtype: float64
#
# payment_type
# 1    0.014232
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_18, dtype: float64
# ratecodeid
# 1    0.006791
# 2    0.000310
# 3    0.004190
# 4    0.003724
# 5    0.001264
# 6    0.000000
# Name: tip_percent_bin_18, dtype: float64
#
# payment_type
# 1    0.008501
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_19, dtype: float64
# ratecodeid
# 1    0.004006
# 2    0.023595
# 3    0.005587
# 4    0.007449
# 5    0.000421
# 6    0.000000
# Name: tip_percent_bin_19, dtype: float64
#
# payment_type
# 1    0.023756
# 2    0.000001
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_20, dtype: float64
# ratecodeid
# 1    0.010228
# 2    0.023906
# 3    0.023743
# 4    0.065177
# 5    0.058107
# 6    0.000000
# Name: tip_percent_bin_20, dtype: float64
#
# payment_type
# 1    0.135210
# 2    0.000000
# 3    0.000000
# 4    0.000314
# 5    0.000000
# Name: tip_percent_bin_21, dtype: float64
# ratecodeid
# 1    0.064730
# 2    0.001242
# 3    0.005587
# 4    0.040968
# 5    0.001685
# 6    0.000000
# Name: tip_percent_bin_21, dtype: float64
#
# payment_type
# 1    0.132282
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_22, dtype: float64
# ratecodeid
# 1    0.063065
# 2    0.118597
# 3    0.011173
# 4    0.013035
# 5    0.001915
# 6    0.000000
# Name: tip_percent_bin_22, dtype: float64
#
# payment_type
# 1    0.071379
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_23, dtype: float64
# ratecodeid
# 1    0.034133
# 2    0.004346
# 3    0.061453
# 4    0.016760
# 5    0.001034
# 6    0.000000
# Name: tip_percent_bin_23, dtype: float64
#
# payment_type
# 1    0.047961
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_24, dtype: float64
# ratecodeid
# 1    0.022951
# 2    0.001242
# 3    0.033520
# 4    0.007449
# 5    0.000306
# 6    0.000000
# Name: tip_percent_bin_24, dtype: float64
#
# payment_type
# 1    0.030816
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_25, dtype: float64
# ratecodeid
# 1    0.014436
# 2    0.005278
# 3    0.020950
# 4    0.020484
# 5    0.016317
# 6    0.000000
# Name: tip_percent_bin_25, dtype: float64
#
# payment_type
# 1    0.040363
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_26, dtype: float64
# ratecodeid
# 1    0.019316
# 2    0.000000
# 3    0.005587
# 4    0.022346
# 5    0.000613
# 6    0.000000
# Name: tip_percent_bin_26, dtype: float64
#
# payment_type
# 1    0.036367
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_27, dtype: float64
# ratecodeid
# 1    0.017411
# 2    0.000621
# 3    0.002793
# 4    0.013035
# 5    0.000306
# 6    0.000000
# Name: tip_percent_bin_27, dtype: float64
#
# payment_type
# 1    0.025912
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_28, dtype: float64
# ratecodeid
# 1    0.012320
# 2    0.034772
# 3    0.009777
# 4    0.011173
# 5    0.000383
# 6    0.000000
# Name: tip_percent_bin_28, dtype: float64
#
# payment_type
# 1    0.018899
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_29, dtype: float64
# ratecodeid
# 1    0.009024
# 2    0.003415
# 3    0.008380
# 4    0.016760
# 5    0.000689
# 6    0.000000
# Name: tip_percent_bin_29, dtype: float64
#
# payment_type
# 1    0.012766
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_30, dtype: float64
# ratecodeid
# 1    0.005917
# 2    0.003415
# 3    0.008380
# 4    0.003724
# 5    0.010151
# 6    0.000000
# Name: tip_percent_bin_30, dtype: float64
#
# payment_type
# 1    0.014463
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_31, dtype: float64
# ratecodeid
# 1    0.006915
# 2    0.000000
# 3    0.005587
# 4    0.011173
# 5    0.000421
# 6    0.000000
# Name: tip_percent_bin_31, dtype: float64
# payment_type
# 1    0.015842
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_32, dtype: float64
# ratecodeid
# 1    0.007585
# 2    0.000000
# 3    0.004190
# 4    0.001862
# 5    0.000153
# 6    0.000000
# Name: tip_percent_bin_32, dtype: float64
#
# payment_type
# 1    0.013212
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_33, dtype: float64
# ratecodeid
# 1    0.006306
# 2    0.000310
# 3    0.002793
# 4    0.001862
# 5    0.001149
# 6    0.000000
# Name: tip_percent_bin_33, dtype: float64
#
# payment_type
# 1    0.010392
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_34, dtype: float64
# ratecodeid
# 1    0.004956
# 2    0.007451
# 3    0.004190
# 4    0.003724
# 5    0.000115
# 6    0.000000
# Name: tip_percent_bin_34, dtype: float64
#
# payment_type
# 1    0.006584
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_35, dtype: float64
# ratecodeid
# 1    0.003148
# 2    0.000931
# 3    0.004190
# 4    0.000000
# 5    0.000153
# 6    0.000000
# Name: tip_percent_bin_35, dtype: float64
#
# payment_type
# 1    0.007571
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_36, dtype: float64
# ratecodeid
# 1    0.003623
# 2    0.000310
# 3    0.001397
# 4    0.001862
# 5    0.000115
# 6    0.000000
# Name: tip_percent_bin_36, dtype: float64
#
# payment_type
# 1    0.003084
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_37, dtype: float64
# ratecodeid
# 1    0.001471
# 2    0.001242
# 3    0.001397
# 4    0.003724
# 5    0.000077
# 6    0.000000
# Name: tip_percent_bin_37, dtype: float64
#
# payment_type
# 1    0.003465
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_38, dtype: float64
# ratecodeid
# 1    0.001647
# 2    0.002794
# 3    0.002793
# 4    0.000000
# 5    0.000306
# 6    0.000000
# Name: tip_percent_bin_38, dtype: float64
#
# payment_type
# 1    0.001872
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_39, dtype: float64
# ratecodeid
# 1    0.000895
# 2    0.000000
# 3    0.001397
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_39, dtype: float64
#
# payment_type
# 1    0.003239
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_40, dtype: float64
# ratecodeid
# 1    0.001543
# 2    0.000000
# 3    0.001397
# 4    0.001862
# 5    0.000421
# 6    0.000000
# Name: tip_percent_bin_40, dtype: float64
#
# payment_type
# 1    0.000946
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_41, dtype: float64
# ratecodeid
# 1    0.000453
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_41, dtype: float64
#
# payment_type
# 1    0.000912
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_42, dtype: float64
# ratecodeid
# 1    0.000437
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_42, dtype: float64
#
# payment_type
# 1    0.00076
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_43, dtype: float64
# ratecodeid
# 1    0.000359
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000306
# 6    0.000000
# Name: tip_percent_bin_43, dtype: float64
#
# payment_type
# 1    0.001426
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_44, dtype: float64
# ratecodeid
# 1    0.000678
# 2    0.000000
# 3    0.000000
# 4    0.001862
# 5    0.000230
# 6    0.000000
# Name: tip_percent_bin_44, dtype: float64
#
# payment_type
# 1    0.000445
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_45, dtype: float64
# ratecodeid
# 1    0.000212
# 2    0.000000
# 3    0.000000
# 4    0.001862
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_45, dtype: float64
#
# payment_type
# 1    0.000453
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_46, dtype: float64
# ratecodeid
# 1    0.000217
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_46, dtype: float64
#
# payment_type
# 1    0.000233
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_47, dtype: float64
# ratecodeid
# 1    0.000112
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_47, dtype: float64
#
# payment_type
# 1    0.000227
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_48, dtype: float64
# ratecodeid
# 1    0.000107
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000115
# 6    0.000000
# Name: tip_percent_bin_48, dtype: float64
#
# payment_type
# 1    0.000185
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_49, dtype: float64
# ratecodeid
# 1    0.000087
# 2    0.000000
# 3    0.000000
# 4    0.001862
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_49, dtype: float64
#
# payment_type
# 1    0.001249
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_50, dtype: float64
# ratecodeid
# 1    0.000573
# 2    0.000000
# 3    0.001397
# 4    0.000000
# 5    0.001341
# 6    0.000000
# Name: tip_percent_bin_50, dtype: float64
#
# payment_type
# 1    0.000089
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_51, dtype: float64
# ratecodeid
# 1    0.000043
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_51, dtype: float64
#
# payment_type
# 1    0.000086
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_52, dtype: float64
# ratecodeid
# 1    0.000041
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_52, dtype: float64
#
# payment_type
# 1    0.000272
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_53, dtype: float64
# ratecodeid
# 1    0.000131
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_53, dtype: float64
#
# payment_type
# 1    0.000108
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_54, dtype: float64
# ratecodeid
# 1    0.000051
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000077
# 6    0.000000
# Name: tip_percent_bin_54, dtype: float64
#
# payment_type
# 1    0.000338
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_55, dtype: float64
# ratecodeid
# 1    0.000161
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_55, dtype: float64
#
# payment_type
# 1    0.000243
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_56, dtype: float64
# ratecodeid
# 1    0.000115
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000077
# 6    0.000000
# Name: tip_percent_bin_56, dtype: float64
#
# payment_type
# 1    0.000392
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_57, dtype: float64
# ratecodeid
# 1    0.000187
# 2    0.000000
# 3    0.000000
# 4    0.001862
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_57, dtype: float64
#
# payment_type
# 1    0.0001
# 2    0.0000
# 3    0.0000
# 4    0.0000
# 5    0.0000
# Name: tip_percent_bin_58, dtype: float64
# ratecodeid
# 1    0.000046
# 2    0.000310
# 3    0.000000
# 4    0.000000
# 5    0.000077
# 6    0.000000
# Name: tip_percent_bin_58, dtype: float64
#
# payment_type
# 1    0.000183
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_59, dtype: float64
# ratecodeid
# 1    0.000086
# 2    0.000000
# 3    0.001397
# 4    0.000000
# 5    0.000077
# 6    0.000000
# Name: tip_percent_bin_59, dtype: float64
#
# payment_type
# 1    0.000343
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_60, dtype: float64
# ratecodeid
# 1    0.000157
# 2    0.000000
# 3    0.000000
# 4    0.001862
# 5    0.000345
# 6    0.000000
# Name: tip_percent_bin_60, dtype: float64
#
# payment_type
# 1    0.000062
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_61, dtype: float64
# ratecodeid
# 1    0.000029
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_61, dtype: float64
#
# payment_type
# 1    0.000296
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_62, dtype: float64
# ratecodeid
# 1    0.000140
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000115
# 6    0.000000
# Name: tip_percent_bin_62, dtype: float64
#
# payment_type
# 1    0.00005
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_63, dtype: float64
# ratecodeid
# 1    0.000024
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_63, dtype: float64
# payment_type
# 1    0.000066
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_64, dtype: float64
# ratecodeid
# 1    0.000032
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_64, dtype: float64
#
# payment_type
# 1    0.000057
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_65, dtype: float64
# ratecodeid
# 1    0.000027
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_65, dtype: float64
#
# payment_type
# 1    0.00001
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_66, dtype: float64
# ratecodeid
# 1    0.000005
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_66, dtype: float64
#
# payment_type
# 1    0.000511
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_67, dtype: float64
# ratecodeid
# 1    0.000242
# 2    0.000310
# 3    0.000000
# 4    0.000000
# 5    0.000115
# 6    0.000000
# Name: tip_percent_bin_67, dtype: float64
#
# payment_type
# 1    0.000048
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_68, dtype: float64
# ratecodeid
# 1    0.000021
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000115
# 6    0.000000
# Name: tip_percent_bin_68, dtype: float64
#
# payment_type
# 1    0.00005
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_69, dtype: float64
# ratecodeid
# 1    0.000023
# 2    0.000310
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_69, dtype: float64
#
# payment_type
# 1    0.000056
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_70, dtype: float64
# ratecodeid
# 1    0.000025
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000077
# 6    0.000000
# Name: tip_percent_bin_70, dtype: float64
#
# payment_type
# 1    0.000168
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_71, dtype: float64
# ratecodeid
# 1    0.000078
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000153
# 6    0.000000
# Name: tip_percent_bin_71, dtype: float64
#
# payment_type
# 1    0.000025
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_72, dtype: float64
# ratecodeid
# 1    0.000011
# 2    0.000310
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_72, dtype: float64
#
# payment_type
# 1    0.000085
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_73, dtype: float64
# ratecodeid
# 1    0.000041
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_73, dtype: float64
#
# payment_type
# 1    0.000044
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_74, dtype: float64
# ratecodeid
# 1    0.000021
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_74, dtype: float64
#
# payment_type
# 1    0.000179
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_75, dtype: float64
# ratecodeid
# 1    0.000083
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000115
# 6    0.000000
# Name: tip_percent_bin_75, dtype: float64
#
# payment_type
# 1    0.000032
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_76, dtype: float64
# ratecodeid
# 1    0.000015
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_76, dtype: float64
#
# payment_type
# 1    0.000142
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_77, dtype: float64
# ratecodeid
# 1    0.000066
# 2    0.000621
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_77, dtype: float64
#
# payment_type
# 1    0.000028
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_78, dtype: float64
# ratecodeid
# 1    0.000013
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_78, dtype: float64
#
# payment_type
# 1    0.000016
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_79, dtype: float64
# ratecodeid
# 1    0.000007
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_79, dtype: float64
#
# payment_type
# 1    0.000132
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_80, dtype: float64
# ratecodeid
# 1    0.000063
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_80, dtype: float64
#
# payment_type
# 1    0.000016
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_81, dtype: float64
# ratecodeid
# 1    0.000008
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_81, dtype: float64
#
# payment_type
# 1    0.000028
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_82, dtype: float64
# ratecodeid
# 1    0.000013
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_82, dtype: float64
#
# payment_type
# 1    0.000127
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_83, dtype: float64
# ratecodeid
# 1    0.000060
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000077
# 6    0.000000
# Name: tip_percent_bin_83, dtype: float64
#
# payment_type
# 1    0.000031
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_84, dtype: float64
# ratecodeid
# 1    0.000015
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_84, dtype: float64
#
# payment_type
# 1    0.000013
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_85, dtype: float64
# ratecodeid
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_85, dtype: float64
#
# payment_type
# 1    0.0001
# 2    0.0000
# 3    0.0000
# 4    0.0000
# 5    0.0000
# Name: tip_percent_bin_86, dtype: float64
# ratecodeid
# 1    0.000048
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_86, dtype: float64
#
# payment_type
# 1    0.000029
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_87, dtype: float64
# ratecodeid
# 1    0.000014
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_87, dtype: float64
#
# payment_type
# 1    0.000019
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_88, dtype: float64
# ratecodeid
# 1    0.000009
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_88, dtype: float64
#
# payment_type
# 1    0.000064
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_89, dtype: float64
# ratecodeid
# 1    0.000030
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_89, dtype: float64
#
# payment_type
# 1    0.000016
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_90, dtype: float64
# ratecodeid
# 1    0.000008
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_90, dtype: float64
#
# payment_type
# 1    0.000117
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_91, dtype: float64
# ratecodeid
# 1    0.000056
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_91, dtype: float64
#
# payment_type
# 1    0.000025
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_92, dtype: float64
# ratecodeid
# 1    0.000011
# 2    0.000310
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_92, dtype: float64
#
# payment_type
# 1    0.000019
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_93, dtype: float64
# ratecodeid
# 1    0.000009
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_93, dtype: float64
#
# payment_type
# 1    0.000016
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_94, dtype: float64
# ratecodeid
# 1    0.000008
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_94, dtype: float64
#
# payment_type
# 1    0.00004
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_95, dtype: float64
# ratecodeid
# 1    0.000019
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_95, dtype: float64
# payment_type
# 1    0.00001
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_96, dtype: float64
# ratecodeid
# 1    0.000005
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_96, dtype: float64
#
# payment_type
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_97, dtype: float64
# ratecodeid
# 1    0.000003
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_97, dtype: float64
#
# payment_type
# 1    0.00001
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_98, dtype: float64
# ratecodeid
# 1    0.000005
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_98, dtype: float64
#
# payment_type
# 1    0.000003
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_99, dtype: float64
# ratecodeid
# 1    0.000001
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_99, dtype: float64
#
# payment_type
# 1    0.000249
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_100, dtype: float64
# ratecodeid
# 1    0.000111
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000460
# 6    0.000000
# Name: tip_percent_bin_100, dtype: float64
#
# payment_type
# 1    0.000012
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_101, dtype: float64
# ratecodeid
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_101, dtype: float64
#
# payment_type
# 1    0.000009
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_102, dtype: float64
# ratecodeid
# 1    0.000004
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_102, dtype: float64
#
# payment_type
# 1    0.000019
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_103, dtype: float64
# ratecodeid
# 1    0.000009
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_103, dtype: float64
#
# payment_type
# 1    0.000023
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_104, dtype: float64
# ratecodeid
# 1    0.000011
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_104, dtype: float64
#
# payment_type
# 1    0.000041
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_105, dtype: float64
# ratecodeid
# 1    0.00002
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# 6    0.00000
# Name: tip_percent_bin_105, dtype: float64
#
# payment_type
# 1    0.000015
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_106, dtype: float64
# ratecodeid
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_106, dtype: float64
#
# payment_type
# 1    0.000028
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_107, dtype: float64
# ratecodeid
# 1    0.000013
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_107, dtype: float64
#
# payment_type
# 1    0.000034
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_108, dtype: float64
# ratecodeid
# 1    0.000016
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_108, dtype: float64
#
# payment_type
# 1    0.000026
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_109, dtype: float64
# ratecodeid
# 1    0.000012
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_109, dtype: float64
#
# payment_type
# 1    0.000015
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_110, dtype: float64
# ratecodeid
# 1    0.000007
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_110, dtype: float64
#
# payment_type
# 1    0.00012
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_111, dtype: float64
# ratecodeid
# 1    0.000057
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_111, dtype: float64
#
# payment_type
# 1    0.000013
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_112, dtype: float64
# ratecodeid
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_112, dtype: float64
#
# payment_type
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_113, dtype: float64
# ratecodeid
# 1    0.000003
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_113, dtype: float64
#
# payment_type
# 1    0.000042
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_114, dtype: float64
# ratecodeid
# 1    0.000020
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_114, dtype: float64
#
# payment_type
# 1    0.000013
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_115, dtype: float64
# ratecodeid
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_115, dtype: float64
#
# payment_type
# 1    0.000015
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_116, dtype: float64
# ratecodeid
# 1    0.000007
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_116, dtype: float64
#
# payment_type
# 1    0.00001
# 2    0.00000
# 3    0.00000
# 4    0.00000
# 5    0.00000
# Name: tip_percent_bin_117, dtype: float64
# ratecodeid
# 1    0.000005
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_117, dtype: float64
#
# payment_type
# 1    0.000029
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_118, dtype: float64
# ratecodeid
# 1    0.000014
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_118, dtype: float64
#
# payment_type
# 1    0.000004
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_119, dtype: float64
# ratecodeid
# 1    0.000001
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000038
# 6    0.000000
# Name: tip_percent_bin_119, dtype: float64
#
# payment_type
# 1    0.000086
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_120, dtype: float64
# ratecodeid
# 1    0.000041
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_120, dtype: float64
#
# payment_type
# 1    0.000007
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_121, dtype: float64
# ratecodeid
# 1    0.000004
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_121, dtype: float64
#
# payment_type
# 1    0.000009
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_122, dtype: float64
# ratecodeid
# 1    0.000004
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_122, dtype: float64
#
# payment_type
# 1    0.000012
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_123, dtype: float64
# ratecodeid
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_123, dtype: float64
#
# payment_type
# 1    0.000003
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_124, dtype: float64
# ratecodeid
# 1    0.000001
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_124, dtype: float64
#
# payment_type
# 1    0.000086
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_125, dtype: float64
# ratecodeid
# 1    0.000041
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_125, dtype: float64
#
# payment_type
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_126, dtype: float64
# ratecodeid
# 1    0.000003
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_126, dtype: float64
#
# payment_type
# 1    0.000013
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_127, dtype: float64
# ratecodeid
# 1    0.000006
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_127, dtype: float64
# payment_type
# 1    0.000016
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_128, dtype: float64
# ratecodeid
# 1    0.000008
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_128, dtype: float64
#
# payment_type
# 1    0.000019
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: tip_percent_bin_129, dtype: float64
# ratecodeid
# 1    0.000009
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# Name: tip_percent_bin_129, dtype: float64
#
# 2018.06.01 17:13
# Time to process: [3.0287057916323343] minutes
#    vendorid  store_and_fwd_flag  ratecodeid  pickup_longitude  \
# 0         2               False           5        -73.979485
# 1         2               False           5        -74.010796
# 2         2               False           1        -73.921410
# 3         2               False           1        -73.921387
# 4         2               False           1        -73.955482
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0        40.684956         -73.979431         40.685020                1
# 1        40.912216         -74.010780         40.912212                1
# 2        40.766708         -73.914413         40.764687                1
# 3        40.766678         -73.931427         40.771584                1
# 4        40.714046         -73.944412         40.714729                1
#
#    trip_distance  fare_amount            ...             \
# 0           0.00          7.8            ...
# 1           0.00         45.0            ...
# 2           0.59          4.0            ...
# 3           0.74          5.0            ...
# 4           0.61          5.0            ...
#
#    payment_type_tip_bin_125_enc  ratecode_tip_bin_125_enc  \
# 0                      0.000086                  0.000000
# 1                      0.000086                  0.000000
# 2                      0.000086                  0.000041
# 3                      0.000000                  0.000041
# 4                      0.000000                  0.000041
#
#    payment_type_tip_bin_126_enc  ratecode_tip_bin_126_enc  \
# 0                      0.000006                  0.000000
# 1                      0.000006                  0.000000
# 2                      0.000006                  0.000003
# 3                      0.000000                  0.000003
# 4                      0.000000                  0.000003
#
#    payment_type_tip_bin_127_enc  ratecode_tip_bin_127_enc  \
# 0                      0.000013                  0.000000
# 1                      0.000013                  0.000000
# 2                      0.000013                  0.000006
# 3                      0.000000                  0.000006
# 4                      0.000000                  0.000006
#
#    payment_type_tip_bin_128_enc  ratecode_tip_bin_128_enc  \
# 0                      0.000016                  0.000000
# 1                      0.000016                  0.000000
# 2                      0.000016                  0.000008
# 3                      0.000000                  0.000008
# 4                      0.000000                  0.000008
#
#    payment_type_tip_bin_129_enc  ratecode_tip_bin_129_enc
# 0                      0.000019                  0.000000
# 1                      0.000019                  0.000000
# 2                      0.000019                  0.000009
# 3                      0.000000                  0.000009
# 4                      0.000000                  0.000009
#
# [5 rows x 435 columns]

# %% [markdown]
# ## Drop Temp Cols: Tip Percent Bins

# %%
start_time = get_time()

# drop temporary tip_percent_bin_* columns
print( len( trips.columns ) )
cols_to_drop = [ col for col in trips.columns if "tip_percent_bin_" in col ]
trips.drop( labels=cols_to_drop, axis=1, inplace=True )
print( len( trips.columns ) )

print_time( start_time, get_time() )
# Out:
# 2018.06.01 17:13
# 435
# 305
# 2018.06.01 17:14
# Time to process: [3.4071147441864014] seconds

# %% [markdown]
# ## Show Mean Encoded Cols for Tip Bins by Payment Type

# %%
cols_to_show = [ col for col in trips.columns if "payment_type_tip_bin_" in col ]
cols_to_show.insert( 0, "payment_type" )
trips[ cols_to_show ].head( 10 )
# Out:
#    payment_type  payment_type_tip_bin_0_enc  payment_type_tip_bin_1_enc  \
# 0             1                    0.141376                    0.001457
# 1             1                    0.141376                    0.001457
# 2             1                    0.141376                    0.001457
# 3             2                    0.999999                    0.000000
# 4             2                    0.999999                    0.000000
# 5             1                    0.141376                    0.001457
# 6             1                    0.141376                    0.001457
# 7             2                    0.999999                    0.000000
# 8             1                    0.141376                    0.001457
# 9             2                    0.999999                    0.000000
#
#    payment_type_tip_bin_2_enc  payment_type_tip_bin_3_enc  \
# 0                    0.001135                    0.001451
# 1                    0.001135                    0.001451
# 2                    0.001135                    0.001451
# 3                    0.000000                    0.000000
# 4                    0.000000                    0.000000
# 5                    0.001135                    0.001451
# 6                    0.001135                    0.001451
# 7                    0.000000                    0.000000
# 8                    0.001135                    0.001451
# 9                    0.000000                    0.000000
#
#    payment_type_tip_bin_4_enc  payment_type_tip_bin_5_enc  \
# 0                    0.002881                    0.004522
# 1                    0.002881                    0.004522
# 2                    0.002881                    0.004522
# 3                    0.000000                    0.000000
# 4                    0.000000                    0.000000
# 5                    0.002881                    0.004522
# 6                    0.002881                    0.004522
# 7                    0.000000                    0.000000
# 8                    0.002881                    0.004522
# 9                    0.000000                    0.000000
#
#    payment_type_tip_bin_6_enc  payment_type_tip_bin_7_enc  \
# 0                    0.006111                    0.007495
# 1                    0.006111                    0.007495
# 2                    0.006111                    0.007495
# 3                    0.000000                    0.000000
# 4                    0.000000                    0.000000
# 5                    0.006111                    0.007495
# 6                    0.006111                    0.007495
# 7                    0.000000                    0.000000
# 8                    0.006111                    0.007495
# 9                    0.000000                    0.000000
#
#    payment_type_tip_bin_8_enc              ...               \
# 0                    0.009599              ...
# 1                    0.009599              ...
# 2                    0.009599              ...
# 3                    0.000000              ...
# 4                    0.000000              ...
# 5                    0.009599              ...
# 6                    0.009599              ...
# 7                    0.000000              ...
# 8                    0.009599              ...
# 9                    0.000000              ...
#
#    payment_type_tip_bin_120_enc  payment_type_tip_bin_121_enc  \
# 0                      0.000086                      0.000007
# 1                      0.000086                      0.000007
# 2                      0.000086                      0.000007
# 3                      0.000000                      0.000000
# 4                      0.000000                      0.000000
# 5                      0.000086                      0.000007
# 6                      0.000086                      0.000007
# 7                      0.000000                      0.000000
# 8                      0.000086                      0.000007
# 9                      0.000000                      0.000000
#
#    payment_type_tip_bin_122_enc  payment_type_tip_bin_123_enc  \
# 0                      0.000009                      0.000012
# 1                      0.000009                      0.000012
# 2                      0.000009                      0.000012
# 3                      0.000000                      0.000000
# 4                      0.000000                      0.000000
# 5                      0.000009                      0.000012
# 6                      0.000009                      0.000012
# 7                      0.000000                      0.000000
# 8                      0.000009                      0.000012
# 9                      0.000000                      0.000000
#
#    payment_type_tip_bin_124_enc  payment_type_tip_bin_125_enc  \
# 0                      0.000003                      0.000086
# 1                      0.000003                      0.000086
# 2                      0.000003                      0.000086
# 3                      0.000000                      0.000000
# 4                      0.000000                      0.000000
# 5                      0.000003                      0.000086
# 6                      0.000003                      0.000086
# 7                      0.000000                      0.000000
# 8                      0.000003                      0.000086
# 9                      0.000000                      0.000000
#
#    payment_type_tip_bin_126_enc  payment_type_tip_bin_127_enc  \
# 0                      0.000006                      0.000013
# 1                      0.000006                      0.000013
# 2                      0.000006                      0.000013
# 3                      0.000000                      0.000000
# 4                      0.000000                      0.000000
# 5                      0.000006                      0.000013
# 6                      0.000006                      0.000013
# 7                      0.000000                      0.000000
# 8                      0.000006                      0.000013
# 9                      0.000000                      0.000000
#
#    payment_type_tip_bin_128_enc  payment_type_tip_bin_129_enc
# 0                      0.000016                      0.000019
# 1                      0.000016                      0.000019
# 2                      0.000016                      0.000019
# 3                      0.000000                      0.000000
# 4                      0.000000                      0.000000
# 5                      0.000016                      0.000019
# 6                      0.000016                      0.000019
# 7                      0.000000                      0.000000
# 8                      0.000016                      0.000019
# 9                      0.000000                      0.000000
#
# [10 rows x 131 columns]

# %% [markdown]
# ## Show Mean Encoded Cols for Tip Bins by RatecodeID

# %%
cols_to_show = [ col for col in trips.columns if "ratecode_tip_bin_" in col ]
cols_to_show.insert( 0, "ratecodeid" )
trips[ cols_to_show ].head( 10 )
# Out:
#    ratecodeid  ratecode_tip_bin_0_enc  ratecode_tip_bin_1_enc  \
# 0           5                0.860152                0.001647
# 1           5                0.860152                0.001647
# 2           1                0.592178                0.000667
# 3           1                0.592178                0.000667
# 4           1                0.592178                0.000667
# 5           1                0.592178                0.000667
# 6           1                0.592178                0.000667
# 7           1                0.592178                0.000667
# 8           1                0.592178                0.000667
# 9           1                0.592178                0.000667
#
#    ratecode_tip_bin_2_enc  ratecode_tip_bin_3_enc  ratecode_tip_bin_4_enc  \
# 0                0.000728                0.000958                0.000919
# 1                0.000728                0.000958                0.000919
# 2                0.000528                0.000675                0.001353
# 3                0.000528                0.000675                0.001353
# 4                0.000528                0.000675                0.001353
# 5                0.000528                0.000675                0.001353
# 6                0.000528                0.000675                0.001353
# 7                0.000528                0.000675                0.001353
# 8                0.000528                0.000675                0.001353
# 9                0.000528                0.000675                0.001353
#
#    ratecode_tip_bin_5_enc  ratecode_tip_bin_6_enc  ratecode_tip_bin_7_enc  \
# 0                0.001839                0.001877                0.002413
# 1                0.001839                0.001877                0.002413
# 2                0.002127                0.002882                0.003537
# 3                0.002127                0.002882                0.003537
# 4                0.002127                0.002882                0.003537
# 5                0.002127                0.002882                0.003537
# 6                0.002127                0.002882                0.003537
# 7                0.002127                0.002882                0.003537
# 8                0.002127                0.002882                0.003537
# 9                0.002127                0.002882                0.003537
#
#    ratecode_tip_bin_8_enc            ...             ratecode_tip_bin_120_enc  \
# 0                0.003792            ...                             0.000000
# 1                0.003792            ...                             0.000000
# 2                0.004517            ...                             0.000041
# 3                0.004517            ...                             0.000041
# 4                0.004517            ...                             0.000041
# 5                0.004517            ...                             0.000041
# 6                0.004517            ...                             0.000041
# 7                0.004517            ...                             0.000041
# 8                0.004517            ...                             0.000041
# 9                0.004517            ...                             0.000041
#
#    ratecode_tip_bin_121_enc  ratecode_tip_bin_122_enc  \
# 0                  0.000000                  0.000000
# 1                  0.000000                  0.000000
# 2                  0.000004                  0.000004
# 3                  0.000004                  0.000004
# 4                  0.000004                  0.000004
# 5                  0.000004                  0.000004
# 6                  0.000004                  0.000004
# 7                  0.000004                  0.000004
# 8                  0.000004                  0.000004
# 9                  0.000004                  0.000004
#
#    ratecode_tip_bin_123_enc  ratecode_tip_bin_124_enc  \
# 0                  0.000000                  0.000000
# 1                  0.000000                  0.000000
# 2                  0.000006                  0.000001
# 3                  0.000006                  0.000001
# 4                  0.000006                  0.000001
# 5                  0.000006                  0.000001
# 6                  0.000006                  0.000001
# 7                  0.000006                  0.000001
# 8                  0.000006                  0.000001
# 9                  0.000006                  0.000001
#
#    ratecode_tip_bin_125_enc  ratecode_tip_bin_126_enc  \
# 0                  0.000000                  0.000000
# 1                  0.000000                  0.000000
# 2                  0.000041                  0.000003
# 3                  0.000041                  0.000003
# 4                  0.000041                  0.000003
# 5                  0.000041                  0.000003
# 6                  0.000041                  0.000003
# 7                  0.000041                  0.000003
# 8                  0.000041                  0.000003
# 9                  0.000041                  0.000003
#
#    ratecode_tip_bin_127_enc  ratecode_tip_bin_128_enc  \
# 0                  0.000000                  0.000000
# 1                  0.000000                  0.000000
# 2                  0.000006                  0.000008
# 3                  0.000006                  0.000008
# 4                  0.000006                  0.000008
# 5                  0.000006                  0.000008
# 6                  0.000006                  0.000008
# 7                  0.000006                  0.000008
# 8                  0.000006                  0.000008
# 9                  0.000006                  0.000008
#
#    ratecode_tip_bin_129_enc
# 0                  0.000000
# 1                  0.000000
# 2                  0.000009
# 3                  0.000009
# 4                  0.000009
# 5                  0.000009
# 6                  0.000009
# 7                  0.000009
# 8                  0.000009
# 9                  0.000009
#
# [10 rows x 131 columns]

# %% [markdown]
# ## Summary

# %%
print( "Columns after mean target encoding:", trips.shape[ 1 ] )
# Out:
# Columns after mean target encoding: 305

# %%
trips.head()
# Out:
#    vendorid  store_and_fwd_flag  ratecodeid  pickup_longitude  \
# 0         2               False           5        -73.979485
# 1         2               False           5        -74.010796
# 2         2               False           1        -73.921410
# 3         2               False           1        -73.921387
# 4         2               False           1        -73.955482
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0        40.684956         -73.979431         40.685020                1
# 1        40.912216         -74.010780         40.912212                1
# 2        40.766708         -73.914413         40.764687                1
# 3        40.766678         -73.931427         40.771584                1
# 4        40.714046         -73.944412         40.714729                1
#
#    trip_distance  fare_amount            ...             \
# 0           0.00          7.8            ...
# 1           0.00         45.0            ...
# 2           0.59          4.0            ...
# 3           0.74          5.0            ...
# 4           0.61          5.0            ...
#
#    payment_type_tip_bin_125_enc  ratecode_tip_bin_125_enc  \
# 0                      0.000086                  0.000000
# 1                      0.000086                  0.000000
# 2                      0.000086                  0.000041
# 3                      0.000000                  0.000041
# 4                      0.000000                  0.000041
#
#    payment_type_tip_bin_126_enc  ratecode_tip_bin_126_enc  \
# 0                      0.000006                  0.000000
# 1                      0.000006                  0.000000
# 2                      0.000006                  0.000003
# 3                      0.000000                  0.000003
# 4                      0.000000                  0.000003
#
#    payment_type_tip_bin_127_enc  ratecode_tip_bin_127_enc  \
# 0                      0.000013                  0.000000
# 1                      0.000013                  0.000000
# 2                      0.000013                  0.000006
# 3                      0.000000                  0.000006
# 4                      0.000000                  0.000006
#
#    payment_type_tip_bin_128_enc  ratecode_tip_bin_128_enc  \
# 0                      0.000016                  0.000000
# 1                      0.000016                  0.000000
# 2                      0.000016                  0.000008
# 3                      0.000000                  0.000008
# 4                      0.000000                  0.000008
#
#    payment_type_tip_bin_129_enc  ratecode_tip_bin_129_enc
# 0                      0.000019                  0.000000
# 1                      0.000019                  0.000000
# 2                      0.000019                  0.000009
# 3                      0.000000                  0.000009
# 4                      0.000000                  0.000009
#
# [5 rows x 305 columns]

# %% [markdown]
# ## Write to Parquet

# %%
start_time = get_time()
trips.to_parquet( "data/green-tripdata-2015-09-cleaned-plus-experimental-features.parquet", compression="gzip" )
print_time( start_time, get_time() )
# Out:
# 2018.06.01 17:23
# 2018.06.01 17:23
# Time to process: [19.018310070037842] seconds

# %% [markdown]
# ## Time to Process Additional Features

# %%
print_time( page_start, get_time(), interval="minutes" )

# %%
trips.columns
